# %%
from tn import *
# Out:
# cuda:0

# %%
# Load image using PIL

# image = Image.open('doradito.png')  # Replace with your image path
# image_shape = (4, 2, 131, 4, 3, 41)

image = Image.open('fruits-llr.png').convert("L")

data = [
    {
        "shape": (8, 8, 4, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5)],
        "ranks": [8, 8, 8, 8],
        "iters": 200,
        "params": [0.25, 0.5, 1, 2, 4, 8, 12],
        "max_rank": 40
    },
    {
        "shape": (8, 8, 4, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)],
        "ranks": [8, 8, 8, 8, 8],
        "iters": 200,
        "params": [0.25, 0.5, 1, 2, 4, 8, 12],
        "max_rank": 25
    },
    {
        "shape": (8, 8, 4, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (3, 5), (1, 4)],
        "ranks": [6, 6, 6, 6, 6, 6, 6],
        "iters": 200,
        "params": [0.25, 0.5, 1, 2, 4, 8, 12],
        "max_rank": 18
    },
    {
        "shape": (8, 8, 4, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (1, 4), (5, 2), (3, 5)],
        "ranks": [4,4,4,4, 4,4,4,4],
        "iters": 200,
        "params": [0.25, 0.5, 1, 2, 4, 8, 12],
        "max_rank": 12
    },
    {
        "shape": (8, 8, 4, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (5, 2), (5, 3), (4, 1), (4, 2), (3, 1)],
        "ranks": [3,3,4,3,3,4,3,3,4,3],
        "iters": 200,
        "params": [0.25, 0.5, 1, 2, 4, 8, 12],
        "max_rank": 10
    }
]

i = 1
for d in data:
    print(d)
    image_shape = d["shape"]
    
    # Define transformation: convert image to tensor
    transform = transforms.ToTensor()
    # device = "cpu"
    
    # Apply transformation
    image_tensor = transform(image).squeeze(0)
    
    # Optional: check shape
    # print(image_tensor.shape)  # (C, H, W)
    objective = image_tensor.reshape(image_shape).to(device)
    
    
    G = nx.Graph()
    G.add_edges_from(d["edges"])
    
    nx.draw(G, with_labels=True)
    plt.savefig("results/img-compression/graph-" + str(i) + ".png", format="PNG")
    plt.show()
    plt.clf()
    
    ntn = TN(G, list(objective.shape), d["ranks"])

    print("Without TnALE:")
    print("Original: " + str(torch.numel(objective)))
    print("Tensor Network: " + str(ntn.get_tn_size()))
    print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
    
    start_time = time.time()
    
    rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Time: {elapsed_time:.2f}s" + "\n")
    
    # If image_tensor is (C, H, W), convert to (H, W, C)
    image_np = TN.eval(ntn).reshape(image_tensor.shape).cpu().numpy()
    
    # Show image
    norm = (image_np - np.min(image_np)) / (np.max(image_np) - np.min(image_np))
    plt.imshow(norm)
    plt.imsave("results/img-compression/fruits-comp" + str(i) + ".png", norm)
    plt.clf()

    graph_data = {}
    graph_data["Original"] = {"data": graph[1]}

    print("Rel Error: " + str(rel_err))

    with open("results/img-compression/data" + str(i) + ".txt", "w") as f:
        f.write("Arbitrary structure\n")
        f.write("Shape: " + str(d["shape"]) + "\n");
        f.write("Edges: " + str(d["edges"]) + "\n");
        f.write("Ranks: " + str(d["ranks"]) + "\n\n");
        f.write("Original: " + str(torch.numel(objective)) + "\n")
        f.write("Tensor Network: " + str(ntn.get_tn_size()) + "\n")
        f.write("CR: " + str(torch.numel(objective) / ntn.get_tn_size()) + "\n")
        f.write("Rel Error: " + str(rel_err) + "\n")
        f.write("Iters: " + str(d["iters"]) + "\n")
        f.write(f"Time: {elapsed_time:.2f}s" + "\n")

    # ---------------------------------------------------------------------------------
    del ntn

    for tuning_param in d["params"]:  
        G = nx.Graph()
        G.add_edges_from(d["edges"])
        
        print("Tuning param " + str(tuning_param))
        print("Doing TnALE Initial Search...")
        
        start_time = time.time()
        G, R = TN.tn_ale(G, d["ranks"], 5, 3, objective, print_iters=True, update_graph=True, tuning_param=tuning_param, max_rank=d["max_rank"])
        end_time = time.time()
        tnale_first_time = end_time - start_time
        
        print("Doing TnALE Concrete Search...")
        
        start_time = time.time()
        G, R = TN.tn_ale(G, R, 2, 3, objective, print_iters=True, tuning_param=tuning_param, max_rank=d["max_rank"])
        end_time = time.time()
        tnale_second_time = end_time - start_time
        
        print("Found structure has ranks " + str(R))

        print("Found graph:")
        nx.draw(G, with_labels=True)
        plt.savefig("results/img-compression/graph-" + str(i) + "-tnale-" + str(tuning_param) + ".png", format="PNG")
        plt.show()
        plt.clf()
        
        
        ntn = TN(G, list(objective.shape), R)
        
        print("With TnALE:")
        print("Original: " + str(torch.numel(objective)))
        print("Tensor Network: " + str(ntn.get_tn_size()))
        print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
        
        start_time = time.time()
        rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
        end_time = time.time()

        als_time = end_time - start_time
        
        print(f"Time: {elapsed_time:.2f}s" + "\n")
        
        # If image_tensor is (C, H, W), convert to (H, W, C)
        image_np = TN.eval(ntn).reshape(image_tensor.shape).cpu().numpy()
        
        # Show image
        norm = (image_np - np.min(image_np)) / (np.max(image_np) - np.min(image_np))
        plt.imshow(norm)
        plt.imsave("results/img-compression/fruits-comp" + str(i) + "-ale-" + str(tuning_param) + ".png", norm)
        plt.clf()
    
        print("Rel Error: " + str(rel_err))
    
        with open("results/img-compression/data" + str(i) + "-ale-" + str(tuning_param) + ".txt", "w") as f:
            f.write("TnALE found structure:\n")
            f.write("Shape: " + str(d["shape"]) + "\n");
            f.write("Edges: " + str(d["edges"]) + "\n");
            f.write("Ranks: " + str(R) + "\n\n");
            f.write("Original: " + str(torch.numel(objective)) + "\n")
            f.write("Tensor Network: " + str(ntn.get_tn_size()) + "\n")
            f.write("CR: " + str(torch.numel(objective) / ntn.get_tn_size()) + "\n")
            f.write("Rel Error: " + str(rel_err) + "\n")
            f.write("Iters: " + str(d["iters"]) + "\n")
            f.write("ALS Time: " + str(als_time) + "\n")
            f.write("TnALE First Batch: " + str(tnale_first_time) + "\n")
            f.write("TnALE Second Batch: " + str(tnale_second_time) + "\n")
            f.write(f"Time: {elapsed_time:.2f}s" + "\n")
        del ntn

        graph_data[str(tuning_param)] = {"data": graph[1]}

    # Print graph
    plt.ylim(0, 0.3)
    plt.xlim(1, 10)
    plt.xticks(range(1, 11))
    for k in graph_data.keys():
        print(k)
        plt.plot(graph_data[k]["data"], label=k)
    plt.legend()
    plt.savefig('results/img-compression/rel_err_fig-' + str(i) + ".png")
    plt.show()

    i += 1
# Out:
# {'shape': (8, 8, 4, 8, 8), 'edges': [(1, 2), (2, 3), (3, 4), (4, 5)], 'ranks': [8, 8, 8, 8], 'iters': 200, 'params': [0.25, 0.5, 1, 2, 4, 8, 16], 'max_rank': 40}
# Without TnALE:
# Original: 16384
# Tensor Network: 1408
# CR: 11.636363636363637
# epoch 10/200 err: 0.13209257594605575
# epoch 20/200 err: 0.13198034325525668
# epoch 30/200 err: 0.1319375947247415
# epoch 40/200 err: 0.1319283725206181
# epoch 50/200 err: 0.1319272005778138
# epoch 60/200 err: 0.1319269158066651
# epoch 70/200 err: 0.1319268172320367
# epoch 80/200 err: 0.13192676246835425
# epoch 90/200 err: 0.13192674056288128
# epoch 100/200 err: 0.1319267296101448
# epoch 110/200 err: 0.1319267296101448
# epoch 120/200 err: 0.1319267296101448
# epoch 130/200 err: 0.1319267296101448
# epoch 140/200 err: 0.1319267186574083
# epoch 150/200 err: 0.1319267296101448
# epoch 160/200 err: 0.1319267296101448
# epoch 170/200 err: 0.1319267186574083
# epoch 180/200 err: 0.1319267296101448
# epoch 190/200 err: 0.1319267296101448
# epoch 200/200 err: 0.1319267296101448
# time_resh: 1478.3625428676605
# Time: 2.93s
#
# Rel Error: 0.1319267296101448
# Tuning param 0.25
# Doing TnALE Initial Search...
# Iter 0 done
# R: [3, 3, 3]
# G edges: [(1, 2), (2, 3), (3, 4)]
# Iter 1 done
# R: [3, 3]
# G edges: [(1, 2), (3, 4)]
# Iter 2 done
# R: [3, 3, 2]
# G edges: [(1, 2), (1, 4), (3, 4)]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [1, 3, 2]
# G edges: [(1, 2), (1, 4), (3, 4)]
# Iter 1 done
# R: [1, 3, 2]
# G edges: [(1, 2), (1, 4), (3, 4)]
# Iter 2 done
# R: [1, 3, 2]
# G edges: [(1, 2), (1, 4), (3, 4)]
# Found structure has ranks [1, 3, 2]
# Found graph:
# With TnALE:
# Original: 16384
# Tensor Network: 96
# CR: 170.66666666666666
# epoch 10/200 err: 0.1753235416453271
# epoch 20/200 err: 0.1753234321179622
# epoch 30/200 err: 0.1753234321179622
# epoch 40/200 err: 0.1753234321179622
# epoch 50/200 err: 0.1753234321179622
# epoch 60/200 err: 0.1753234321179622
# epoch 70/200 err: 0.1753234321179622
# epoch 80/200 err: 0.1753234321179622
# epoch 90/200 err: 0.1753234321179622
# epoch 100/200 err: 0.1753234321179622
# epoch 110/200 err: 0.1753234321179622
# epoch 120/200 err: 0.1753234321179622
# epoch 130/200 err: 0.1753234321179622
# epoch 140/200 err: 0.1753234321179622
# epoch 150/200 err: 0.1753234321179622
# epoch 160/200 err: 0.1753234321179622
# epoch 170/200 err: 0.1753234321179622
# epoch 180/200 err: 0.1753234321179622
# epoch 190/200 err: 0.1753234321179622
# epoch 200/200 err: 0.1753234321179622
# time_resh: 862.4178533554077
# Time: 2.93s
#
# Rel Error: 0.1753234321179622
# Tuning param 0.5
# Doing TnALE Initial Search...
# Iter 0 done
# R: [3, 3, 3, 3, 1]
# G edges: [(1, 2), (1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [3, 3, 3, 1]
# G edges: [(1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 2 done
# R: [3, 3, 3, 1]
# G edges: [(1, 4), (2, 3), (3, 4), (4, 5)]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [4, 2, 3, 1]
# G edges: [(1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [5, 2, 3, 1]
# G edges: [(1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 2 done
# R: [5, 2, 3, 1]
# G edges: [(1, 4), (2, 3), (3, 4), (4, 5)]
# Found structure has ranks [5, 2, 3, 1]
# Found graph:
# With TnALE:
# Original: 16384
# Tensor Network: 208
# CR: 78.76923076923077
# epoch 10/200 err: 0.16038706488830443
# epoch 20/200 err: 0.1599485392247723
# epoch 30/200 err: 0.15994850636656285
# epoch 40/200 err: 0.15994851731929935
# epoch 50/200 err: 0.15994851731929935
# epoch 60/200 err: 0.15994850636656285
# epoch 70/200 err: 0.15994852827203584
# epoch 80/200 err: 0.15994850636656285
# epoch 90/200 err: 0.15994850636656285
# epoch 100/200 err: 0.15994850636656285
# epoch 110/200 err: 0.15994851731929935
# epoch 120/200 err: 0.15994852827203584
# epoch 130/200 err: 0.15994852827203584
# epoch 140/200 err: 0.15994850636656285
# epoch 150/200 err: 0.15994850636656285
# epoch 160/200 err: 0.15994850636656285
# epoch 170/200 err: 0.15994850636656285
# epoch 180/200 err: 0.15994850636656285
# epoch 190/200 err: 0.15994852827203584
# epoch 200/200 err: 0.15994852827203584
# time_resh: 995.2760775089264
# Time: 2.93s
#
# Rel Error: 0.15994851731929935
# Tuning param 1
# Doing TnALE Initial Search...
# Iter 0 done
# R: [8, 8, 8, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [8, 8, 8, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Iter 2 done
# R: [8, 8, 8, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [6, 4, 7, 2]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [6, 4, 5, 2]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Iter 2 done
# R: [4, 4, 5, 2]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Found structure has ranks [4, 4, 5, 2]
# Found graph:
# With TnALE:
# Original: 16384
# Tensor Network: 336
# CR: 48.76190476190476
# epoch 10/200 err: 0.15888651808388798
# epoch 20/200 err: 0.1588769453921969
# epoch 30/200 err: 0.1588769453921969
# epoch 40/200 err: 0.1588769453921969
# epoch 50/200 err: 0.1588769453921969
# epoch 60/200 err: 0.1588769453921969
# epoch 70/200 err: 0.1588769453921969
# epoch 80/200 err: 0.1588769453921969
# epoch 90/200 err: 0.1588769453921969
# epoch 100/200 err: 0.1588769453921969
# epoch 110/200 err: 0.1588769453921969
# epoch 120/200 err: 0.1588769453921969
# epoch 130/200 err: 0.1588769453921969
# epoch 140/200 err: 0.1588769453921969
# epoch 150/200 err: 0.1588769453921969
# epoch 160/200 err: 0.1588769453921969
# epoch 170/200 err: 0.1588769453921969
# epoch 180/200 err: 0.1588769453921969
# epoch 190/200 err: 0.1588769453921969
# epoch 200/200 err: 0.1588769453921969
# time_resh: 994.7483019828796
# Time: 2.93s
#
# Rel Error: 0.1588769453921969
# Tuning param 2
# Doing TnALE Initial Search...
# Iter 0 done
# R: [8, 3, 3, 3, 2]
# G edges: [(1, 2), (1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [8, 7, 3, 3, 2]
# G edges: [(1, 2), (1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 2 done
# R: [8, 7, 3, 3, 2]
# G edges: [(1, 2), (1, 4), (2, 3), (3, 4), (4, 5)]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [6, 7, 3, 3, 2]
# G edges: [(1, 2), (1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [6, 7, 3, 3, 2]
# G edges: [(1, 2), (1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 2 done
# R: [6, 7, 3, 3, 2]
# G edges: [(1, 2), (1, 4), (2, 3), (3, 4), (4, 5)]
# Found structure has ranks [6, 7, 3, 3, 2]
# Found graph:
# With TnALE:
# Original: 16384
# Tensor Network: 868
# CR: 18.87557603686636
# epoch 10/200 err: 0.12427329688671532
# epoch 20/200 err: 0.12161337006676701
# epoch 30/200 err: 0.12092551630980752
# epoch 40/200 err: 0.12051607016165275
# epoch 50/200 err: 0.1202654715507927
# epoch 60/200 err: 0.12009856279944234
# epoch 70/200 err: 0.11996683423769348
# epoch 80/200 err: 0.1198526848180089
# epoch 90/200 err: 0.11975231394082701
# epoch 100/200 err: 0.11966596256635058
# epoch 110/200 err: 0.11959203159505227
# epoch 120/200 err: 0.11952716948956656
# epoch 130/200 err: 0.11946848472746043
# epoch 140/200 err: 0.11941391819427404
# epoch 150/200 err: 0.11936154220838537
# epoch 160/200 err: 0.11930917717523318
# epoch 170/200 err: 0.11925614402515519
# epoch 180/200 err: 0.11920514808406409
# epoch 190/200 err: 0.1191590699216564
# epoch 200/200 err: 0.11911843526928353
# time_resh: 1271.8381888866425
# Time: 2.93s
#
# Rel Error: 0.11911464562245848
# Tuning param 4
# Doing TnALE Initial Search...
# Iter 0 done
# R: [8, 12, 12, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [8, 12, 12, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Iter 2 done
# R: [8, 16, 12, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [8, 15, 12, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [8, 15, 12, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Iter 2 done
# R: [8, 15, 12, 3]
# G edges: [(1, 2), (2, 3), (3, 4), (4, 5)]
# Found structure has ranks [8, 15, 12, 3]
# Found graph:
# With TnALE:
# Original: 16384
# Tensor Network: 2056
# CR: 7.968871595330739
# epoch 10/200 err: 0.11015796868971887
# epoch 20/200 err: 0.11012722435839527
# epoch 30/200 err: 0.11012577859717877
# epoch 40/200 err: 0.11012356614440806
# epoch 50/200 err: 0.11011380725619668
# epoch 60/200 err: 0.1100799633004468
# epoch 70/200 err: 0.11003504612810688
# epoch 80/200 err: 0.11001253825462273
# epoch 90/200 err: 0.1099999316549243
# epoch 100/200 err: 0.10999055611249003
# epoch 110/200 err: 0.1099835463611373
# epoch 120/200 err: 0.10997881477897421
# epoch 130/200 err: 0.10997595611475068
# epoch 140/200 err: 0.10997432415701387
# epoch 150/200 err: 0.10997342603262181
# epoch 160/200 err: 0.10997295506495279
# epoch 170/200 err: 0.10997270315201356
# epoch 180/200 err: 0.1099725607664392
# epoch 190/200 err: 0.10997249505002027
# epoch 200/200 err: 0.10997245123907431
# time_resh: 2406.991804599762
# Time: 2.93s
#
# Rel Error: 0.10997245123907431
# Tuning param 8
# Doing TnALE Initial Search...
# Iter 0 done
# R: [8, 16, 12, 3, 5]
# G edges: [(1, 2), (1, 4), (2, 3), (3, 4), (4, 5)]
# Iter 1 done
# R: [12, 16, 3, 5]
# G edges: [(1, 2), (1, 4), (2, 3), (4, 5)]
# Iter 2 done
# R: [12, 20, 3, 5]
# G edges: [(1, 2), (1, 4), (2, 3), (4, 5)]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [12, 18, 4, 6]
# G edges: [(1, 2), (1, 4), (2, 3), (4, 5)]
# Iter 1 done
# R: [13, 20, 4, 6]
# G edges: [(1, 2), (1, 4), (2, 3), (4, 5)]
# Iter 2 done
# R: [13, 20, 4, 6]
# G edges: [(1, 2), (1, 4), (2, 3), (4, 5)]
# Found structure has ranks [13, 20, 4, 6]
# Found graph:
# With TnALE:
# Original: 16384
# Tensor Network: 3520
# CR: 4.654545454545454
# epoch 10/200 err: 0.08456543769369367
# epoch 20/200 err: 0.08443243313814389
# epoch 30/200 err: 0.08443190193042419
# epoch 40/200 err: 0.08443192931226541
# epoch 50/200 err: 0.08443197312321137
# epoch 60/200 err: 0.08443191288316068
# epoch 70/200 err: 0.08443187454858296
# epoch 80/200 err: 0.08443191288316068
# epoch 90/200 err: 0.08443188550131946
# epoch 100/200 err: 0.08443188002495121
# epoch 110/200 err: 0.08443188550131946
# epoch 120/200 err: 0.08443195669410664
# epoch 130/200 err: 0.08443195121773839
# epoch 140/200 err: 0.08443188550131946
# epoch 150/200 err: 0.08443192383589716
# epoch 160/200 err: 0.08443188550131946
# epoch 170/200 err: 0.08443194026500189
# epoch 180/200 err: 0.08443192931226541
# epoch 190/200 err: 0.08443195669410664
# epoch 200/200 err: 0.08443185811947823
# time_resh: 2817.269092321396
# Time: 2.93s
#
# Rel Error: 0.08443195669410664
# Tuning param 16
# Doing TnALE Initial Search...
# Iter 0 done
# R: [8, 16, 16, 12, 5]
# G edges: [(1, 2), (2, 3), (2, 5), (3, 4), (4, 5)]
# Iter 1 done
# R: [8, 16, 16, 12, 5]
# G edges: [(1, 2), (2, 3), (2, 5), (3, 4), (4, 5)]
# Iter 2 done
# R: [8, 16, 16, 16, 5]
# G edges: [(1, 2), (2, 3), (2, 5), (3, 4), (4, 5)]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [8, 17, 16, 16, 3]
# G edges: [(1, 2), (2, 3), (2, 5), (3, 4), (4, 5)]
# Iter 1 done
# R: [8, 17, 16, 17, 3]
# G edges: [(1, 2), (2, 3), (2, 5), (3, 4), (4, 5)]
# Iter 2 done
# R: [8, 17, 16, 17, 3]
# G edges: [(1, 2), (2, 3), (2, 5), (3, 4), (4, 5)]
# Found structure has ranks [8, 17, 16, 17, 3]
# Found graph:
# With TnALE:
# Original: 16384
# Tensor Network: 19420
# CR: 0.8436663233779609
# epoch 10/200 err: 0.04718804153067384
# epoch 20/200 err: 0.047042079887857996
# epoch 30/200 err: 0.0469356028600837
# epoch 40/200 err: 0.04681019402728879
# epoch 50/200 err: 0.0468362560637635
# epoch 60/200 err: 0.046751427119658996
# epoch 70/200 err: 0.04696429355331569
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 156
#     153 print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
#     155 start_time = time.time()
# --> 156 rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
#     157 end_time = time.time()
#     159 als_time = end_time - start_time
#
# File ~\Desktop\TFG\tn.py:501, in TN.als(tn, t, err, iter_num, print_iters, tikhonov, max_time)
#     499     core = torch.linalg.solve(ATA, ATb)
#     500 else:
# --> 501     core = torch.linalg.pinv(cont_mat) @ obj_mat
#     503 end_time = time.time()
#     506 # Ara busquem el core
#
# KeyboardInterrupt:
