# %%
from tn import *
# Out:
# cuda:0

# %%
# Load image using PIL

# image = Image.open('doradito.png')  # Replace with your image path
# image_shape = (4, 2, 131, 4, 3, 41)

image = Image.open('lenna-lr.png').convert("L")

data = [
    #{
    #    "shape": (8, 8, 16, 8, 8),
    #    "edges": [(1, 2), (2, 3), (3, 4), (4, 5)],
    #    "ranks": [12, 12, 12, 12],
    #    "iters": 20
    #},
    #{
    #    "shape": (8, 8, 16, 8, 8),
    #    "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)],
    #    "ranks": [12, 12, 12, 12, 12],
    #    "iters": 20
    #},
    #{
    #    "shape": (8, 8, 16, 8, 8),
    #    "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (3, 5), (1, 4)],
    #    "ranks": [9, 9, 12, 9, 9, 12, 8],
    #    "iters": 20
    #},
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (1, 4), (5, 2), (3, 5)],
        "ranks": [6,6,6,6, 6,6,6,6],
        "iters": 20
    }
]

i = 4
for d in data:
    print(d)
    image_shape = d["shape"]
    
    # Define transformation: convert image to tensor
    transform = transforms.ToTensor()
    # device = "cpu"
    
    # Apply transformation
    image_tensor = transform(image).squeeze(0)
    
    # Optional: check shape
    # print(image_tensor.shape)  # (C, H, W)
    objective = image_tensor.reshape(image_shape).to(device)
    
    
    G = nx.Graph()
    G.add_edges_from(d["edges"])
    
    nx.draw(G, with_labels=True)
    plt.savefig("results/graph-" + str(i) + ".png", format="PNG")
    plt.show()
    plt.clf()
    
    ntn = TN(G, list(objective.shape), d["ranks"])

    print("Without TnALE:")
    print("Original: " + str(torch.numel(objective)))
    print("Tensor Network: " + str(ntn.get_tn_size()))
    print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
    
    start_time = time.time()
    
    rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Time: {elapsed_time:.2f}s" + "\n")
    
    # If image_tensor is (C, H, W), convert to (H, W, C)
    image_np = TN.eval(ntn).reshape(image_tensor.shape).cpu().numpy()
    
    # Show image
    norm = (image_np - np.min(image_np)) / (np.max(image_np) - np.min(image_np))
    plt.imshow(norm)
    plt.imsave("results/lenna-comp" + str(i) + ".png", norm)
    plt.clf()

    graph_data = {}
    graph_data["Original"] = {"data": graph[1], "color": "red"}

    print("Rel Error: " + str(rel_err))

    with open("results/data" + str(i) + ".txt", "w") as f:
        f.write("Arbitrary structure\n")
        f.write("Shape: " + str(d["shape"]) + "\n");
        f.write("Edges: " + str(d["edges"]) + "\n");
        f.write("Ranks: " + str(d["ranks"]) + "\n\n");
        f.write("Original: " + str(torch.numel(objective)) + "\n")
        f.write("Tensor Network: " + str(ntn.get_tn_size()) + "\n")
        f.write("CR: " + str(torch.numel(objective) / ntn.get_tn_size()) + "\n")
        f.write("Rel Error: " + str(rel_err) + "\n")
        f.write("Iters: " + str(d["iters"]) + "\n")
        f.write(f"Time: {elapsed_time:.2f}s" + "\n")

    # ---------------------------------------------------------------------------------
    del ntn

    for tuning_param, color in [(0.5, "orange"), (1, "blue"), (2, "indigo"), (4, "magenta"), (8, "indigo")]:
        print("Tuning param " + str(tuning_param))
        print("Doing TnALE Initial Search...")
        G, R = TN.tn_ale(G, d["ranks"], 5, 3, objective, print_iters=True, tuning_param=tuning_param, max_rank=75)
        print("Doing TnALE Concrete Search...")
        G, R = TN.tn_ale(G, R, 2, 5, objective, print_iters=True, tuning_param=tuning_param, max_rank=75)
        print("Found structure has ranks " + str(R))
        ntn = TN(G, list(objective.shape), R)
        
        print("With TnALE:")
        print("Original: " + str(torch.numel(objective)))
        print("Tensor Network: " + str(ntn.get_tn_size()))
        print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
        
        start_time = time.time()
        rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"Time: {elapsed_time:.2f}s" + "\n")
        
        # If image_tensor is (C, H, W), convert to (H, W, C)
        image_np = TN.eval(ntn).reshape(image_tensor.shape).cpu().numpy()
        
        # Show image
        norm = (image_np - np.min(image_np)) / (np.max(image_np) - np.min(image_np))
        plt.imshow(norm)
        plt.imsave("results/lenna-comp" + str(i) + "-ale-" + str(tuning_param) + ".png", norm)
        plt.clf()
    
        print("Rel Error: " + str(rel_err))
    
        with open("results/data" + str(i) + "-ale-" + str(tuning_param) + ".txt", "w") as f:
            f.write("TnALE found structure:\n")
            f.write("Shape: " + str(d["shape"]) + "\n");
            f.write("Edges: " + str(d["edges"]) + "\n");
            f.write("Ranks: " + str(R) + "\n\n");
            f.write("Original: " + str(torch.numel(objective)) + "\n")
            f.write("Tensor Network: " + str(ntn.get_tn_size()) + "\n")
            f.write("CR: " + str(torch.numel(objective) / ntn.get_tn_size()) + "\n")
            f.write("Rel Error: " + str(rel_err) + "\n")
            f.write("Iters: " + str(d["iters"]) + "\n")
            f.write(f"Time: {elapsed_time:.2f}s" + "\n")
        del ntn

        graph_data[str(tuning_param)] = {"data": graph[1], "color": color}

    # Print graph
    plt.ylim(0, 0.3)
    plt.xlim(1, 20)
    for k in graph_data.keys():
        print(k)
        plt.plot(graph_data[k]["data"], label=k)
    plt.legend()
    plt.savefig('results/rel_err_fig-' + str(i) + ".png")
    plt.show()

    i += 1
# Out:
# {'shape': (8, 8, 16, 8, 8), 'edges': [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (1, 4), (5, 2), (3, 5)], 'ranks': [6, 6, 6, 6, 6, 6, 6, 6], 'iters': 20}
# Without TnALE:
# Original: 65536
# Tensor Network: 19008
# CR: 3.4478114478114477
# epoch 1/20 err: 2300.0410881272896
# epoch 2/20 err: 0.1468623986208904
# epoch 3/20 err: 0.11192223722248973
# epoch 4/20 err: 0.1022562816692509
# epoch 5/20 err: 0.09731758002270993
# epoch 6/20 err: 0.09430592467614698
# epoch 7/20 err: 0.09230539799373369
# epoch 8/20 err: 0.09076932536795766
# epoch 9/20 err: 0.08957287364911354
# epoch 10/20 err: 0.08864326741745147
# epoch 11/20 err: 0.08779161089476438
# epoch 12/20 err: 0.08708026247937266
# epoch 13/20 err: 0.0865422869745126
# epoch 14/20 err: 0.08595831094335342
# epoch 15/20 err: 0.08546415263375702
# epoch 16/20 err: 0.08501457123649306
# epoch 17/20 err: 0.08463841546728103
# epoch 18/20 err: 0.08429303166150315
# epoch 19/20 err: 0.08395228828971289
# epoch 20/20 err: 0.08363939436614629
# epoch 21/20 err: 0.08333680111094453
# time_resh: 5.838874578475952
# Time: 6.17s
#
# Rel Error: 0.08333680111094453
# Tuning param 0.5
# Doing TnALE Initial Search...
# Iter 0 done
# R: [3, 1, 8, 2, 1, 3, 3, 5]
# Iter 1 done
# R: [3, 1, 8, 2, 1, 3, 3, 5]
# Iter 2 done
# R: [6, 1, 8, 2, 1, 1, 3, 6]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [6, 1, 8, 2, 1, 1, 3, 5]
# Iter 1 done
# R: [6, 1, 8, 2, 1, 1, 3, 6]
# Iter 2 done
# R: [6, 1, 8, 2, 1, 1, 3, 6]
# Iter 3 done
# R: [6, 1, 8, 2, 1, 1, 3, 6]
# Iter 4 done
# R: [6, 1, 8, 2, 1, 1, 3, 6]
# Found structure has ranks [6, 1, 8, 2, 1, 1, 3, 6]
# With TnALE:
# Original: 65536
# Tensor Network: 1104
# CR: 59.36231884057971
# epoch 1/20 err: 66.86254163933967
# epoch 2/20 err: 0.32652371319259776
# epoch 3/20 err: 0.2005921221145398
# epoch 4/20 err: 0.17631378214917307
# epoch 5/20 err: 0.17028908890786798
# epoch 6/20 err: 0.16851755190085865
# epoch 7/20 err: 0.16757094443317114
# epoch 8/20 err: 0.16685841195423978
# epoch 9/20 err: 0.16624850287827367
# epoch 10/20 err: 0.16570810449195106
# epoch 11/20 err: 0.16522730625188833
# epoch 12/20 err: 0.16480005779872706
# epoch 13/20 err: 0.16441895360212114
# epoch 14/20 err: 0.16407450746515786
# epoch 15/20 err: 0.1637565487611328
# epoch 16/20 err: 0.16345509850368317
# epoch 17/20 err: 0.16316127279411288
# epoch 18/20 err: 0.16286740601875513
# epoch 19/20 err: 0.16256694134020552
# epoch 20/20 err: 0.16225410217102226
# epoch 21/20 err: 0.1619245766035177
# time_resh: 0.24117112159729004
# Time: 0.33s
#
# Rel Error: 0.1619245766035177
# Tuning param 1
# Doing TnALE Initial Search...
# Iter 0 done
# R: [1, 2, 5, 1, 4, 8, 3, 6]
# Iter 1 done
# R: [1, 2, 5, 1, 4, 8, 3, 6]
# Iter 2 done
# R: [1, 2, 5, 1, 4, 8, 3, 6]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [1, 2, 5, 1, 3, 8, 2, 6]
# Iter 1 done
# R: [1, 2, 5, 1, 3, 7, 2, 6]
# Iter 2 done
# R: [1, 2, 5, 1, 3, 7, 2, 6]
# Iter 3 done
# R: [1, 2, 5, 1, 3, 7, 2, 6]
# Iter 4 done
# R: [1, 2, 5, 1, 3, 7, 2, 6]
# Found structure has ranks [1, 2, 5, 1, 3, 7, 2, 6]
# With TnALE:
# Original: 65536
# Tensor Network: 2584
# CR: 25.362229102167184
# epoch 1/20 err: 99.2108355858374
# epoch 2/20 err: 0.1878944711104375
# epoch 3/20 err: 0.14984636193808176
# epoch 4/20 err: 0.14513370691884053
# epoch 5/20 err: 0.1439461938530758
# epoch 6/20 err: 0.1431603452548592
# epoch 7/20 err: 0.14215714913199518
# epoch 8/20 err: 0.14178903541283547
# epoch 9/20 err: 0.1420894727141934
# epoch 10/20 err: 0.1413251562772232
# epoch 11/20 err: 0.1410497143518576
# epoch 12/20 err: 0.14117417106517754
# epoch 13/20 err: 0.1406729631287268
# epoch 14/20 err: 0.14071118168829447
# epoch 15/20 err: 0.1402559537452491
# epoch 16/20 err: 0.14000142799431736
# epoch 17/20 err: 0.14002515033089716
# epoch 18/20 err: 0.13968015665010056
# epoch 19/20 err: 0.1398497035980967
# epoch 20/20 err: 0.13940333217655573
# epoch 21/20 err: 0.13966418205876263
# time_resh: 0.39807796478271484
# Time: 0.49s
#
# Rel Error: 0.13966418205876263
# Tuning param 2
# Doing TnALE Initial Search...
# Iter 0 done
# R: [1, 2, 12, 1, 4, 5, 1, 7]
# Iter 1 done
# R: [1, 2, 12, 1, 4, 5, 1, 7]
# Iter 2 done
# R: [1, 2, 12, 1, 4, 5, 1, 7]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [1, 2, 12, 1, 4, 5, 1, 7]
# Iter 1 done
# R: [1, 2, 12, 1, 4, 5, 1, 7]
# Iter 2 done
# R: [1, 2, 12, 1, 4, 5, 1, 7]
# Iter 3 done
# R: [1, 2, 12, 1, 4, 5, 1, 7]
# Iter 4 done
# R: [1, 2, 12, 1, 4, 5, 1, 7]
# Found structure has ranks [1, 2, 12, 1, 4, 5, 1, 7]
# With TnALE:
# Original: 65536
# Tensor Network: 4112
# CR: 15.937743190661479
# epoch 1/20 err: 112.18741768362895
# epoch 2/20 err: 0.21662475309879695
# epoch 3/20 err: 0.13299973860257397
# epoch 4/20 err: 0.12236549284584702
# epoch 5/20 err: 0.11923426761467676
# epoch 6/20 err: 0.11851973660075371
# epoch 7/20 err: 0.11792717097570887
# epoch 8/20 err: 0.1176088837453838
# epoch 9/20 err: 0.11728534009425857
# epoch 10/20 err: 0.1174413490209752
# epoch 11/20 err: 0.11715365580233843
# epoch 12/20 err: 0.11701236211614302
# epoch 13/20 err: 0.11690125178376093
# epoch 14/20 err: 0.11683866752360927
# epoch 15/20 err: 0.1169182256425947
# epoch 16/20 err: 0.11671846796359359
# epoch 17/20 err: 0.11669456767526797
# epoch 18/20 err: 0.11686334806189742
# epoch 19/20 err: 0.11662481059089945
# epoch 20/20 err: 0.11651901143370082
# epoch 21/20 err: 0.11683952990514679
# time_resh: 0.8022522926330566
# Time: 0.90s
#
# Rel Error: 0.11683952990514679
# Tuning param 4
# Doing TnALE Initial Search...
# Iter 0 done
# R: [1, 3, 10, 1, 8, 9, 2, 8]
# Iter 1 done
# R: [1, 3, 10, 1, 8, 9, 2, 8]
# Iter 2 done
# R: [1, 3, 10, 1, 8, 9, 2, 8]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [1, 1, 9, 1, 7, 9, 2, 8]
# Iter 1 done
# R: [1, 1, 9, 1, 7, 9, 2, 8]
# Iter 2 done
# R: [1, 1, 9, 1, 7, 9, 2, 8]
# Iter 3 done
# R: [1, 1, 9, 1, 7, 9, 2, 8]
# Iter 4 done
# R: [1, 1, 9, 1, 7, 9, 2, 8]
# Found structure has ranks [1, 1, 9, 1, 7, 9, 2, 8]
# With TnALE:
# Original: 65536
# Tensor Network: 6496
# CR: 10.088669950738916
# epoch 1/20 err: 175.25484453095152
# epoch 2/20 err: 0.20140519732986964
# epoch 3/20 err: 0.1080693286860733
# epoch 4/20 err: 0.10406934987601965
# epoch 5/20 err: 0.10301285036097922
# epoch 6/20 err: 0.10256227654051732
# epoch 7/20 err: 0.10235140372169924
# epoch 8/20 err: 0.10234555869127825
# epoch 9/20 err: 0.10209015002591525
# epoch 10/20 err: 0.10209863011103422
# epoch 11/20 err: 0.10221927455041449
# epoch 12/20 err: 0.10227584951699516
# epoch 13/20 err: 0.10224839019375277
# epoch 14/20 err: 0.10216081055760878
# epoch 15/20 err: 0.10206657826388962
# epoch 16/20 err: 0.10196912230585163
# epoch 17/20 err: 0.10196422863284109
# epoch 18/20 err: 0.1019332376518736
# epoch 19/20 err: 0.10187433562400121
# epoch 20/20 err: 0.1019095563810813
# epoch 21/20 err: 0.10185005889929015
# time_resh: 1.413818120956421
# Time: 1.51s
#
# Rel Error: 0.10185005889929015
# Tuning param 8
# Doing TnALE Initial Search...
# Iter 0 done
# R: [10, 9, 1, 1, 7, 5, 6, 9]
# Iter 1 done
# R: [10, 9, 1, 1, 7, 6, 6, 9]
# Iter 2 done
# R: [10, 9, 1, 1, 7, 6, 6, 9]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [11, 9, 1, 1, 7, 5, 6, 10]
# Iter 1 done
# R: [11, 9, 1, 1, 7, 5, 6, 10]
# Iter 2 done
# R: [11, 9, 1, 1, 7, 5, 4, 10]
# Iter 3 done
# R: [11, 9, 1, 1, 7, 5, 4, 10]
# Iter 4 done
# R: [11, 9, 1, 1, 7, 5, 4, 10]
# Found structure has ranks [11, 9, 1, 1, 7, 5, 4, 10]
# With TnALE:
# Original: 65536
# Tensor Network: 22288
# CR: 2.940416367552046
# epoch 1/20 err: 676.5537810146623
# epoch 2/20 err: 0.14640473410778662
# epoch 3/20 err: 0.07857098642978315
# epoch 4/20 err: 0.07467840834264067
# epoch 5/20 err: 0.07372833081590931
# epoch 6/20 err: 0.07323062715999198
# epoch 7/20 err: 0.07298349325081045
# epoch 8/20 err: 0.07270561475538644
# epoch 9/20 err: 0.07255269945132822
# epoch 10/20 err: 0.07246036987242996
# epoch 11/20 err: 0.07243106258875001
# epoch 12/20 err: 0.07243209607773546
# epoch 13/20 err: 0.07230742719118008
# epoch 14/20 err: 0.07217192378102233
# epoch 15/20 err: 0.07206384547261739
# epoch 16/20 err: 0.0719670397228815
# epoch 17/20 err: 0.07188318338480428
# epoch 18/20 err: 0.07186620268167258
# epoch 19/20 err: 0.0717812649445245
# epoch 20/20 err: 0.07170286351188701
# epoch 21/20 err: 0.0716436671792042
# time_resh: 32.139405965805054
# Time: 32.23s
#
# Rel Error: 0.0716436671792042
# Original
# 0.5
# 1
# 2
# 4
# 8
