# %%
from tn import *
# Out:
# cuda:0

# %%
# Load image using PIL

# image = Image.open('doradito.png')  # Replace with your image path
# image_shape = (4, 2, 131, 4, 3, 41)

image = Image.open('lenna-lr.png').convert("L")

data = [
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5)],
        "ranks": [12, 12, 12, 12],
        "iters": 10,
        "params": [0.5, 1, 2, 4, 8, 16, 32],
        "max_rank": 40
    },
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)],
        "ranks": [12, 12, 12, 12, 12],
        "iters": 10,
        "params": [0.5, 1, 2, 4, 8, 16, 32],
        "max_rank": 25
    },
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (3, 5), (1, 4)],
        "ranks": [9, 9, 12, 9, 9, 12, 8],
        "iters": 10,
        "params": [0.5, 1, 2, 4, 8],
        "max_rank": 18
    },
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (1, 4), (5, 2), (3, 5)],
        "ranks": [6,6,6,6, 6,6,6,6],
        "iters": 10,
        "params": [0.5, 1, 2, 4, 8],
        "max_rank": 12
    },
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (5, 2), (5, 3), (4, 1), (4, 2), (3, 1)],
        "ranks": [4,4,4,4,4,4,4,4,4,4],
        "iters": 10,
        "params": [0.5, 1, 2, 4],
        "max_rank": 10
    }
]

i = 1
for d in data:
    print(d)
    image_shape = d["shape"]
    
    # Define transformation: convert image to tensor
    transform = transforms.ToTensor()
    # device = "cpu"
    
    # Apply transformation
    image_tensor = transform(image).squeeze(0)
    
    # Optional: check shape
    # print(image_tensor.shape)  # (C, H, W)
    objective = image_tensor.reshape(image_shape).to(device)
    
    
    G = nx.Graph()
    G.add_edges_from(d["edges"])
    
    nx.draw(G, with_labels=True)
    plt.savefig("results/graph-" + str(i) + ".png", format="PNG")
    plt.show()
    plt.clf()
    
    ntn = TN(G, list(objective.shape), d["ranks"])

    print("Without TnALE:")
    print("Original: " + str(torch.numel(objective)))
    print("Tensor Network: " + str(ntn.get_tn_size()))
    print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
    
    start_time = time.time()
    
    rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Time: {elapsed_time:.2f}s" + "\n")
    
    # If image_tensor is (C, H, W), convert to (H, W, C)
    image_np = TN.eval(ntn).reshape(image_tensor.shape).cpu().numpy()
    
    # Show image
    norm = (image_np - np.min(image_np)) / (np.max(image_np) - np.min(image_np))
    plt.imshow(norm)
    plt.imsave("results/lenna-comp" + str(i) + ".png", norm)
    plt.clf()

    graph_data = {}
    graph_data["Original"] = {"data": graph[1]}

    print("Rel Error: " + str(rel_err))

    with open("results/data" + str(i) + ".txt", "w") as f:
        f.write("Arbitrary structure\n")
        f.write("Shape: " + str(d["shape"]) + "\n");
        f.write("Edges: " + str(d["edges"]) + "\n");
        f.write("Ranks: " + str(d["ranks"]) + "\n\n");
        f.write("Original: " + str(torch.numel(objective)) + "\n")
        f.write("Tensor Network: " + str(ntn.get_tn_size()) + "\n")
        f.write("CR: " + str(torch.numel(objective) / ntn.get_tn_size()) + "\n")
        f.write("Rel Error: " + str(rel_err) + "\n")
        f.write("Iters: " + str(d["iters"]) + "\n")
        f.write(f"Time: {elapsed_time:.2f}s" + "\n")

    # ---------------------------------------------------------------------------------
    del ntn

    for tuning_param in d["params"]:
        print("Tuning param " + str(tuning_param))
        print("Doing TnALE Initial Search...")
        G, R = TN.tn_ale(G, d["ranks"], 5, 3, objective, print_iters=True, tuning_param=tuning_param, max_rank=d["max_rank"])
        print("Doing TnALE Concrete Search...")
        G, R = TN.tn_ale(G, R, 2, 5, objective, print_iters=True, tuning_param=tuning_param, max_rank=d["max_rank"])
        print("Found structure has ranks " + str(R))
        ntn = TN(G, list(objective.shape), R)
        
        print("With TnALE:")
        print("Original: " + str(torch.numel(objective)))
        print("Tensor Network: " + str(ntn.get_tn_size()))
        print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
        
        start_time = time.time()
        rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"Time: {elapsed_time:.2f}s" + "\n")
        
        # If image_tensor is (C, H, W), convert to (H, W, C)
        image_np = TN.eval(ntn).reshape(image_tensor.shape).cpu().numpy()
        
        # Show image
        norm = (image_np - np.min(image_np)) / (np.max(image_np) - np.min(image_np))
        plt.imshow(norm)
        plt.imsave("results/lenna-comp" + str(i) + "-ale-" + str(tuning_param) + ".png", norm)
        plt.clf()
    
        print("Rel Error: " + str(rel_err))
    
        with open("results/data" + str(i) + "-ale-" + str(tuning_param) + ".txt", "w") as f:
            f.write("TnALE found structure:\n")
            f.write("Shape: " + str(d["shape"]) + "\n");
            f.write("Edges: " + str(d["edges"]) + "\n");
            f.write("Ranks: " + str(R) + "\n\n");
            f.write("Original: " + str(torch.numel(objective)) + "\n")
            f.write("Tensor Network: " + str(ntn.get_tn_size()) + "\n")
            f.write("CR: " + str(torch.numel(objective) / ntn.get_tn_size()) + "\n")
            f.write("Rel Error: " + str(rel_err) + "\n")
            f.write("Iters: " + str(d["iters"]) + "\n")
            f.write(f"Time: {elapsed_time:.2f}s" + "\n")
        del ntn

        graph_data[str(tuning_param)] = {"data": graph[1]}

    # Print graph
    plt.ylim(0, 0.3)
    plt.xlim(1, 10)
    plt.xticks(range(1, 11))
    for k in graph_data.keys():
        print(k)
        plt.plot(graph_data[k]["data"], label=k)
    plt.legend()
    plt.savefig('results/rel_err_fig-' + str(i) + ".png")
    plt.show()

    i += 1
# Out:
# {'shape': (8, 8, 16, 8, 8), 'edges': [(1, 2), (2, 3), (3, 4), (4, 5)], 'ranks': [12, 12, 12, 12], 'iters': 10, 'params': [0.5, 1, 2, 4, 8, 16, 32], 'max_rank': 40}
# Without TnALE:
# Original: 65536
# Tensor Network: 4800
# CR: 13.653333333333334
# epoch 1/10 err: 225.74401384015596
# epoch 2/10 err: 0.2142355866477713
# epoch 3/10 err: 0.1480720872119057
# epoch 4/10 err: 0.14239802735288073
# epoch 5/10 err: 0.14129471284008907
# epoch 6/10 err: 0.1409170444810374
# epoch 7/10 err: 0.14074351415165365
# epoch 8/10 err: 0.14064925448074284
# epoch 9/10 err: 0.14059137909755798
# epoch 10/10 err: 0.14055279094590278
# epoch 11/10 err: 0.1405257833463229
# time_resh: 0.4297788143157959
# Time: 0.55s
#
# Rel Error: 0.1405257833463229
# Tuning param 0.5
# Doing TnALE Initial Search...
# Iter 0 done
# R: [12, 7, 7, 2]
# Iter 1 done
# R: [7, 7, 7, 2]
# Iter 2 done
# R: [7, 7, 7, 2]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [7, 7, 5, 2]
# Iter 1 done
# R: [7, 8, 5, 2]
# Iter 2 done
# R: [8, 8, 5, 3]
# Iter 3 done
# R: [8, 8, 5, 3]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 125
#     123 G, R = TN.tn_ale(G, d["ranks"], 5, 3, objective, print_iters=True, tuning_param=tuning_param, max_rank=75)
#     124 print("Doing TnALE Concrete Search...")
# --> 125 G, R = TN.tn_ale(G, R, 2, 5, objective, print_iters=True, tuning_param=tuning_param, max_rank=75)
#     126 print("Found structure has ranks " + str(R))
#     127 ntn = TN(G, list(objective.shape), R)
#
# File ~\Desktop\TFG\tn.py:264, in TN.tn_ale(G0, R0, radius, iters, objective, print_iters, max_rank, tuning_param)
#     262 # We now update G
#     263 for nG in graph_neighborhood(G):
# --> 264     evaluation = TN.evaluate_structure(nG, R, objective, tuning_param=tuning_param)
#     265     if h > evaluation:
#     266         p = (nG, R)
#
# File ~\Desktop\TFG\tn.py:312, in TN.evaluate_structure(G, R, objective, tuning_param)
#     308 @staticmethod
#     309 def evaluate_structure(G, R, objective, tuning_param=2):
#     310     # We do one iteration of ALS):
#     311     tn = TN(G, objective.shape, R)
# --> 312     err = TN.als(tn, objective, 0, iter_num=2)[0]
#     313     icr = tn.get_tn_size() / objective.numel()
#     314     return icr + err * tuning_param
#
# File ~\Desktop\TFG\tn.py:438, in TN.als(tn, t, err, iter_num, print_iters)
#     428 start_time = time.time()
#     430 # core = torch.linalg.lstsq(cont_mat, obj_mat)[0]
#     431
#     432 #lambda_reg = 1e-5
#     433 #ATA = cont_mat.T @ cont_mat + lambda_reg * torch.eye(cont_mat.shape[1], device=cont_mat.device, dtype=cont_mat.dtype)
#     434 #ATb = cont_mat.T @ obj_mat
#     435 #core = torch.linalg.solve(ATA, ATb)
# --> 438 core = torch.linalg.pinv(cont_mat) @ obj_mat
#     440 end_time = time.time()
#     442 # Ara busquem el core
#
# KeyboardInterrupt:
