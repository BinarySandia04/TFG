# %%
from tn import *
# Out:
# cuda:0

# %%
# Load image using PIL

# image = Image.open('doradito.png')  # Replace with your image path
# image_shape = (4, 2, 131, 4, 3, 41)

image = Image.open('lenna-lr.png').convert("L")

data = [
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5)],
        "ranks": [12, 12, 12, 12],
        "iters": 10,
        "params": [0.5, 1, 2, 4, 8, 16, 32],
        "max_rank": 40
    },
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)],
        "ranks": [12, 12, 12, 12, 12],
        "iters": 10,
        "params": [0.5, 1, 2, 4, 8, 16, 32],
        "max_rank": 25
    },
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (3, 5), (1, 4)],
        "ranks": [9, 9, 12, 9, 9, 12, 8],
        "iters": 10,
        "params": [0.5, 1, 2, 4, 8],
        "max_rank": 18
    },
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (1, 4), (5, 2), (3, 5)],
        "ranks": [6,6,6,6, 6,6,6,6],
        "iters": 10,
        "params": [0.5, 1, 2, 4, 8],
        "max_rank": 12
    },
    {
        "shape": (8, 8, 16, 8, 8),
        "edges": [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (5, 2), (5, 3), (4, 1), (4, 2), (3, 1)],
        "ranks": [4,4,4,4,4,4,4,4,4,4],
        "iters": 10,
        "params": [0.5, 1, 2, 4],
        "max_rank": 10
    }
]

i = 1
for d in data:
    print(d)
    image_shape = d["shape"]
    
    # Define transformation: convert image to tensor
    transform = transforms.ToTensor()
    # device = "cpu"
    
    # Apply transformation
    image_tensor = transform(image).squeeze(0)
    
    # Optional: check shape
    # print(image_tensor.shape)  # (C, H, W)
    objective = image_tensor.reshape(image_shape).to(device)
    
    
    G = nx.Graph()
    G.add_edges_from(d["edges"])
    
    nx.draw(G, with_labels=True)
    plt.savefig("results/graph-" + str(i) + ".png", format="PNG")
    plt.show()
    plt.clf()
    
    ntn = TN(G, list(objective.shape), d["ranks"])

    print("Without TnALE:")
    print("Original: " + str(torch.numel(objective)))
    print("Tensor Network: " + str(ntn.get_tn_size()))
    print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
    
    start_time = time.time()
    
    rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Time: {elapsed_time:.2f}s" + "\n")
    
    # If image_tensor is (C, H, W), convert to (H, W, C)
    image_np = TN.eval(ntn).reshape(image_tensor.shape).cpu().numpy()
    
    # Show image
    norm = (image_np - np.min(image_np)) / (np.max(image_np) - np.min(image_np))
    plt.imshow(norm)
    plt.imsave("results/lenna-comp" + str(i) + ".png", norm)
    plt.clf()

    graph_data = {}
    graph_data["Original"] = {"data": graph[1]}

    print("Rel Error: " + str(rel_err))

    with open("results/data" + str(i) + ".txt", "w") as f:
        f.write("Arbitrary structure\n")
        f.write("Shape: " + str(d["shape"]) + "\n");
        f.write("Edges: " + str(d["edges"]) + "\n");
        f.write("Ranks: " + str(d["ranks"]) + "\n\n");
        f.write("Original: " + str(torch.numel(objective)) + "\n")
        f.write("Tensor Network: " + str(ntn.get_tn_size()) + "\n")
        f.write("CR: " + str(torch.numel(objective) / ntn.get_tn_size()) + "\n")
        f.write("Rel Error: " + str(rel_err) + "\n")
        f.write("Iters: " + str(d["iters"]) + "\n")
        f.write(f"Time: {elapsed_time:.2f}s" + "\n")

    # ---------------------------------------------------------------------------------
    del ntn

    for tuning_param in d["params"]:
        print("Tuning param " + str(tuning_param))
        print("Doing TnALE Initial Search...")
        G, R = TN.tn_ale(G, d["ranks"], 5, 3, objective, print_iters=True, tuning_param=tuning_param, max_rank=d["max_rank"])
        print("Doing TnALE Concrete Search...")
        G, R = TN.tn_ale(G, R, 2, 5, objective, print_iters=True, tuning_param=tuning_param, max_rank=d["max_rank"])
        print("Found structure has ranks " + str(R))
        ntn = TN(G, list(objective.shape), R)
        
        print("With TnALE:")
        print("Original: " + str(torch.numel(objective)))
        print("Tensor Network: " + str(ntn.get_tn_size()))
        print("CR: " + str(torch.numel(objective) / ntn.get_tn_size()))
        
        start_time = time.time()
        rel_err, graph = TN.als(ntn, objective, 1e-3, iter_num=d["iters"], print_iters=True)
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"Time: {elapsed_time:.2f}s" + "\n")
        
        # If image_tensor is (C, H, W), convert to (H, W, C)
        image_np = TN.eval(ntn).reshape(image_tensor.shape).cpu().numpy()
        
        # Show image
        norm = (image_np - np.min(image_np)) / (np.max(image_np) - np.min(image_np))
        plt.imshow(norm)
        plt.imsave("results/lenna-comp" + str(i) + "-ale-" + str(tuning_param) + ".png", norm)
        plt.clf()
    
        print("Rel Error: " + str(rel_err))
    
        with open("results/data" + str(i) + "-ale-" + str(tuning_param) + ".txt", "w") as f:
            f.write("TnALE found structure:\n")
            f.write("Shape: " + str(d["shape"]) + "\n");
            f.write("Edges: " + str(d["edges"]) + "\n");
            f.write("Ranks: " + str(R) + "\n\n");
            f.write("Original: " + str(torch.numel(objective)) + "\n")
            f.write("Tensor Network: " + str(ntn.get_tn_size()) + "\n")
            f.write("CR: " + str(torch.numel(objective) / ntn.get_tn_size()) + "\n")
            f.write("Rel Error: " + str(rel_err) + "\n")
            f.write("Iters: " + str(d["iters"]) + "\n")
            f.write(f"Time: {elapsed_time:.2f}s" + "\n")
        del ntn

        graph_data[str(tuning_param)] = {"data": graph[1]}

    # Print graph
    plt.ylim(0, 0.3)
    plt.xlim(1, 10)
    plt.xticks(range(1, 11))
    for k in graph_data.keys():
        print(k)
        plt.plot(graph_data[k]["data"], label=k)
    plt.legend()
    plt.savefig('results/rel_err_fig-' + str(i) + ".png")
    plt.show()

    i += 1
# Out:
# {'shape': (8, 8, 16, 8, 8), 'edges': [(1, 2), (2, 3), (3, 4), (4, 5)], 'ranks': [12, 12, 12, 12], 'iters': 10, 'params': [0.5, 1, 2, 4, 8, 16, 32], 'max_rank': 40}
# Without TnALE:
# Original: 65536
# Tensor Network: 4800
# CR: 13.653333333333334
# epoch 1/10 err: 260.7001372911408
# epoch 2/10 err: 0.21847781938259175
# epoch 3/10 err: 0.14613472655496698
# epoch 4/10 err: 0.14253095730702173
# epoch 5/10 err: 0.14172558877114627
# epoch 6/10 err: 0.14138149853767468
# epoch 7/10 err: 0.14119959078764072
# epoch 8/10 err: 0.14108233427572928
# epoch 9/10 err: 0.14099019633717266
# epoch 10/10 err: 0.14090820164812884
# epoch 11/10 err: 0.140832298384231
# time_resh: 0.4305591583251953
# Time: 0.53s
#
# Rel Error: 0.140832298384231
# Tuning param 0.5
# Doing TnALE Initial Search...
# Iter 0 done
# R: [12, 7, 7, 2]
# Iter 1 done
# R: [7, 7, 7, 2]
# Iter 2 done
# R: [7, 7, 7, 2]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [8, 7, 5, 3]
# Iter 1 done
# R: [8, 7, 5, 3]
# Iter 2 done
# R: [8, 7, 6, 3]
# Iter 3 done
# R: [8, 7, 6, 3]
# Iter 4 done
# R: [8, 7, 6, 3]
# Found structure has ranks [8, 7, 6, 3]
# With TnALE:
# Original: 65536
# Tensor Network: 1352
# CR: 48.47337278106509
# epoch 1/10 err: 42.995405559694376
# epoch 2/10 err: 0.2562072306667474
# epoch 3/10 err: 0.20588541999185475
# epoch 4/10 err: 0.19557165164078627
# epoch 5/10 err: 0.19097210548891885
# epoch 6/10 err: 0.1889249212276064
# epoch 7/10 err: 0.18818304039920764
# epoch 8/10 err: 0.18778029453258865
# epoch 9/10 err: 0.18744555361007148
# epoch 10/10 err: 0.18710400945542494
# epoch 11/10 err: 0.1867538825511907
# time_resh: 0.09680008888244629
# Time: 0.13s
#
# Rel Error: 0.1867538825511907
# Tuning param 1
# Doing TnALE Initial Search...
# Iter 0 done
# R: [12, 12, 7, 7]
# Iter 1 done
# R: [12, 12, 7, 7]
# Iter 2 done
# R: [12, 12, 7, 7]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [12, 12, 7, 7]
# Iter 1 done
# R: [12, 13, 8, 5]
# Iter 2 done
# R: [10, 11, 8, 5]
# Iter 3 done
# R: [10, 11, 8, 5]
# Iter 4 done
# R: [10, 11, 8, 3]
# Found structure has ranks [10, 11, 8, 3]
# With TnALE:
# Original: 65536
# Tensor Network: 2584
# CR: 25.362229102167184
# epoch 1/10 err: 82.32671436795538
# epoch 2/10 err: 0.22928629358708996
# epoch 3/10 err: 0.15920992272075846
# epoch 4/10 err: 0.15541218606984972
# epoch 5/10 err: 0.15458397126752785
# epoch 6/10 err: 0.15421921125434737
# epoch 7/10 err: 0.1539875043926704
# epoch 8/10 err: 0.15382421313297026
# epoch 9/10 err: 0.15370649120880048
# epoch 10/10 err: 0.15361973288840652
# epoch 11/10 err: 0.1535540002512131
# time_resh: 0.150803804397583
# Time: 0.19s
#
# Rel Error: 0.1535540002512131
# Tuning param 2
# Doing TnALE Initial Search...
# Iter 0 done
# R: [12, 16, 12, 7]
# Iter 1 done
# R: [12, 16, 12, 7]
# Iter 2 done
# R: [12, 16, 12, 7]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [10, 17, 10, 7]
# Iter 1 done
# R: [10, 17, 10, 5]
# Iter 2 done
# R: [8, 17, 10, 5]
# Iter 3 done
# R: [8, 17, 10, 3]
# Iter 4 done
# R: [8, 17, 10, 3]
# Found structure has ranks [8, 17, 10, 3]
# With TnALE:
# Original: 65536
# Tensor Network: 4136
# CR: 15.845261121856867
# epoch 1/10 err: 147.72514657474647
# epoch 2/10 err: 0.19392696685136782
# epoch 3/10 err: 0.13860627261835132
# epoch 4/10 err: 0.13386077865770504
# epoch 5/10 err: 0.13254164974299934
# epoch 6/10 err: 0.13189380956797805
# epoch 7/10 err: 0.1314218952266114
# epoch 8/10 err: 0.13106777125239372
# epoch 9/10 err: 0.13083001403135827
# epoch 10/10 err: 0.13068347761295857
# epoch 11/10 err: 0.1305969109329063
# time_resh: 0.21524310111999512
# Time: 0.25s
#
# Rel Error: 0.1305969109329063
# Tuning param 4
# Doing TnALE Initial Search...
# Iter 0 done
# R: [12, 20, 12, 7]
# Iter 1 done
# R: [12, 20, 12, 7]
# Iter 2 done
# R: [12, 24, 16, 7]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [10, 24, 14, 5]
# Iter 1 done
# R: [10, 25, 14, 5]
# Iter 2 done
# R: [8, 25, 14, 5]
# Iter 3 done
# R: [8, 25, 14, 5]
# Iter 4 done
# R: [8, 25, 14, 5]
# Found structure has ranks [8, 25, 14, 5]
# With TnALE:
# Original: 65536
# Tensor Network: 7864
# CR: 8.333672431332655
# epoch 1/10 err: 231.55467164946157
# epoch 2/10 err: 0.13649539532062469
# epoch 3/10 err: 0.11330349182938665
# epoch 4/10 err: 0.1107206249030163
# epoch 5/10 err: 0.10978830832937915
# epoch 6/10 err: 0.1092840478360575
# epoch 7/10 err: 0.10898129031770575
# epoch 8/10 err: 0.10867830693752273
# epoch 9/10 err: 0.10851897852631644
# epoch 10/10 err: 0.108404767726978
# epoch 11/10 err: 0.10841745021101792
# time_resh: 0.3702361583709717
# Time: 0.40s
#
# Rel Error: 0.10841745021101792
# Tuning param 8
# Doing TnALE Initial Search...
# Iter 0 done
# R: [16, 20, 16, 12]
# Iter 1 done
# R: [16, 28, 20, 7]
# Iter 2 done
# R: [16, 32, 20, 7]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [17, 32, 20, 7]
# Iter 1 done
# R: [15, 32, 21, 7]
# Iter 2 done
# R: [15, 32, 21, 7]
# Iter 3 done
# R: [15, 32, 21, 7]
# Iter 4 done
# R: [15, 32, 21, 7]
# Found structure has ranks [15, 32, 21, 7]
# With TnALE:
# Original: 65536
# Tensor Network: 15944
# CR: 4.110386352232815
# epoch 1/10 err: 410.91857946541984
# epoch 2/10 err: 0.128246565339665
# epoch 3/10 err: 0.0949379750558741
# epoch 4/10 err: 0.09088425481857737
# epoch 5/10 err: 0.0896634100219576
# epoch 6/10 err: 0.08915467335779832
# epoch 7/10 err: 0.08890886039811474
# epoch 8/10 err: 0.08875901133952328
# epoch 9/10 err: 0.08866164435735821
# epoch 10/10 err: 0.08859192149447928
# epoch 11/10 err: 0.088647914695737
# time_resh: 1.0590946674346924
# Time: 1.10s
#
# Rel Error: 0.088647914695737
# Tuning param 16
# Doing TnALE Initial Search...
# Iter 0 done
# R: [16, 20, 20, 7]
# Iter 1 done
# R: [16, 28, 20, 7]
# Iter 2 done
# R: [16, 36, 24, 7]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [14, 37, 26, 8]
# Iter 1 done
# R: [12, 38, 26, 8]
# Iter 2 done
# R: [12, 38, 27, 9]
# Iter 3 done
# R: [12, 38, 27, 9]
# Iter 4 done
# R: [12, 38, 27, 9]
# Found structure has ranks [12, 38, 27, 9]
# With TnALE:
# Original: 65536
# Tensor Network: 22176
# CR: 2.9552669552669553
# epoch 1/10 err: 683.2444337515218
# epoch 2/10 err: 0.11494472709265503
# epoch 3/10 err: 0.0821479807842777
# epoch 4/10 err: 0.07743514781329063
# epoch 5/10 err: 0.07608913449636753
# epoch 6/10 err: 0.0755815066084708
# epoch 7/10 err: 0.07529755722079454
# epoch 8/10 err: 0.07511638865493557
# epoch 9/10 err: 0.07500046678111792
# epoch 10/10 err: 0.07492146989456168
# epoch 11/10 err: 0.07486534665164353
# time_resh: 2.0223326683044434
# Time: 2.07s
#
# Rel Error: 0.07486534665164353
# Tuning param 32
# Doing TnALE Initial Search...
# Iter 0 done
# R: [16, 20, 16, 12]
# Iter 1 done
# R: [16, 28, 24, 12]
# Iter 2 done
# R: [16, 36, 28, 12]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [16, 38, 29, 10]
# Iter 1 done
# R: [16, 40, 31, 8]
# Iter 2 done
# R: [14, 40, 32, 6]
# Iter 3 done
# R: [14, 40, 32, 6]
# Iter 4 done
# R: [14, 40, 32, 6]
# Found structure has ranks [14, 40, 32, 6]
# With TnALE:
# Original: 65536
# Tensor Network: 26656
# CR: 2.458583433373349
# epoch 1/10 err: 470.4983290604838
# epoch 2/10 err: 0.11070582068662216
# epoch 3/10 err: 0.07803300408062518
# epoch 4/10 err: 0.07286586030251359
# epoch 5/10 err: 0.07108608960511029
# epoch 6/10 err: 0.0703286448432486
# epoch 7/10 err: 0.06987703753380126
# epoch 8/10 err: 0.06964087503418043
# epoch 9/10 err: 0.06954120836791529
# epoch 10/10 err: 0.0694086137843722
# epoch 11/10 err: 0.06931638002564476
# time_resh: 2.514200448989868
# Time: 2.55s
#
# Rel Error: 0.06931638002564476
# Original
# 0.5
# 1
# 2
# 4
# 8
# 16
# 32
# {'shape': (8, 8, 16, 8, 8), 'edges': [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1)], 'ranks': [12, 12, 12, 12, 12], 'iters': 10, 'params': [0.5, 1, 2, 4, 8, 16, 32], 'max_rank': 25}
# Without TnALE:
# Original: 65536
# Tensor Network: 6912
# CR: 9.481481481481481
# epoch 1/10 err: 893.0135820438037
# epoch 2/10 err: 0.19661199861274295
# epoch 3/10 err: 0.13448782585565497
# epoch 4/10 err: 0.12209025624941892
# epoch 5/10 err: 0.11725870208676621
# epoch 6/10 err: 0.11456440999030956
# epoch 7/10 err: 0.11273127430204861
# epoch 8/10 err: 0.11134835653075789
# epoch 9/10 err: 0.11022515933251778
# epoch 10/10 err: 0.10928432845227208
# epoch 11/10 err: 0.10848900050144064
# time_resh: 0.41434359550476074
# Time: 0.46s
#
# Rel Error: 0.10848900050144064
# Tuning param 0.5
# Doing TnALE Initial Search...
# Iter 0 done
# R: [7, 7, 7, 2, 7]
# Iter 1 done
# R: [7, 7, 7, 2, 11]
# Iter 2 done
# R: [11, 7, 7, 2, 6]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [11, 5, 7, 2, 6]
# Iter 1 done
# R: [11, 5, 7, 2, 6]
# Iter 2 done
# R: [11, 5, 5, 2, 6]
# Iter 3 done
# R: [11, 5, 5, 2, 7]
# Iter 4 done
# R: [11, 5, 5, 2, 7]
# Found structure has ranks [11, 5, 5, 2, 7]
# With TnALE:
# Original: 65536
# Tensor Network: 1432
# CR: 45.76536312849162
# epoch 1/10 err: 128.86018873397902
# epoch 2/10 err: 0.24669042605371252
# epoch 3/10 err: 0.17764581940974994
# epoch 4/10 err: 0.16733313245775233
# epoch 5/10 err: 0.16422449340970766
# epoch 6/10 err: 0.1627571854451022
# epoch 7/10 err: 0.1618428009320072
# epoch 8/10 err: 0.16118599472671485
# epoch 9/10 err: 0.160686853768235
# epoch 10/10 err: 0.16028484708579102
# epoch 11/10 err: 0.15994103062423612
# time_resh: 0.12415766716003418
# Time: 0.16s
#
# Rel Error: 0.15994103062423612
# Tuning param 1
# Doing TnALE Initial Search...
# Iter 0 done
# R: [7, 7, 2, 7, 12]
# Iter 1 done
# R: [7, 7, 2, 7, 12]
# Iter 2 done
# R: [7, 7, 2, 7, 12]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [8, 8, 2, 8, 13]
# Iter 1 done
# R: [8, 9, 2, 8, 13]
# Iter 2 done
# R: [8, 9, 2, 8, 13]
# Iter 3 done
# R: [8, 9, 2, 8, 13]
# Iter 4 done
# R: [8, 9, 2, 8, 13]
# Found structure has ranks [8, 9, 2, 8, 13]
# With TnALE:
# Original: 65536
# Tensor Network: 2728
# CR: 24.023460410557185
# epoch 1/10 err: 212.29131916340998
# epoch 2/10 err: 0.25657167584222373
# epoch 3/10 err: 0.1507587205389934
# epoch 4/10 err: 0.13919260993229182
# epoch 5/10 err: 0.1362064838169587
# epoch 6/10 err: 0.1348845350515113
# epoch 7/10 err: 0.1340748956737357
# epoch 8/10 err: 0.133455240317536
# epoch 9/10 err: 0.13293395121099721
# epoch 10/10 err: 0.13249482105665228
# epoch 11/10 err: 0.13213438663975524
# time_resh: 0.1964120864868164
# Time: 0.23s
#
# Rel Error: 0.13213438663975524
# Tuning param 2
# Doing TnALE Initial Search...
# Iter 0 done
# R: [7, 11, 7, 12, 16]
# Iter 1 done
# R: [11, 11, 2, 12, 15]
# Iter 2 done
# R: [11, 11, 2, 12, 15]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [11, 11, 2, 12, 15]
# Iter 1 done
# R: [9, 11, 2, 10, 15]
# Iter 2 done
# R: [9, 9, 2, 8, 15]
# Iter 3 done
# R: [9, 9, 2, 8, 15]
# Iter 4 done
# R: [9, 9, 2, 8, 14]
# Found structure has ranks [9, 9, 2, 8, 14]
# With TnALE:
# Original: 65536
# Tensor Network: 2952
# CR: 22.200542005420054
# epoch 1/10 err: 274.9008556905519
# epoch 2/10 err: 0.19855714808071104
# epoch 3/10 err: 0.1469055861407457
# epoch 4/10 err: 0.13893757770331425
# epoch 5/10 err: 0.1363340752187246
# epoch 6/10 err: 0.1353036251015557
# epoch 7/10 err: 0.13423594200371913
# epoch 8/10 err: 0.1334758690314574
# epoch 9/10 err: 0.1327392720010504
# epoch 10/10 err: 0.13219768270689025
# epoch 11/10 err: 0.1317466024083825
# time_resh: 0.20662927627563477
# Time: 0.25s
#
# Rel Error: 0.1317466024083825
# Tuning param 4
# Doing TnALE Initial Search...
# Iter 0 done
# R: [16, 7, 7, 12, 16]
# Iter 1 done
# R: [20, 7, 7, 16, 20]
# Iter 2 done
# R: [20, 11, 7, 11, 20]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [20, 9, 7, 11, 20]
# Iter 1 done
# R: [21, 9, 7, 11, 21]
# Iter 2 done
# R: [21, 9, 7, 11, 21]
# Iter 3 done
# R: [21, 9, 7, 11, 21]
# Iter 4 done
# R: [21, 9, 7, 11, 21]
# Found structure has ranks [21, 9, 7, 11, 21]
# With TnALE:
# Original: 65536
# Tensor Network: 7280
# CR: 9.002197802197802
# epoch 1/10 err: 1008.9578337589027
# epoch 2/10 err: 0.1426581380509126
# epoch 3/10 err: 0.11700089107283439
# epoch 4/10 err: 0.110640231779685
# epoch 5/10 err: 0.1075820352072875
# epoch 6/10 err: 0.10580889663456564
# epoch 7/10 err: 0.10460681890283385
# epoch 8/10 err: 0.10372486267326887
# epoch 9/10 err: 0.10301785354275644
# epoch 10/10 err: 0.10241302293584462
# epoch 11/10 err: 0.10188055709080762
# time_resh: 0.4845726490020752
# Time: 0.52s
#
# Rel Error: 0.10188055709080762
# Tuning param 8
# Doing TnALE Initial Search...
# Iter 0 done
# R: [16, 20, 7, 16, 20]
# Iter 1 done
# R: [20, 24, 7, 24, 20]
# Iter 2 done
# R: [24, 24, 7, 24, 15]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [24, 24, 5, 25, 15]
# Iter 1 done
# R: [24, 25, 5, 25, 13]
# Iter 2 done
# R: [24, 25, 5, 25, 13]
# Iter 3 done
# R: [24, 25, 5, 25, 13]
# Iter 4 done
# R: [24, 25, 5, 25, 13]
# Found structure has ranks [24, 25, 5, 25, 13]
# With TnALE:
# Original: 65536
# Tensor Network: 12960
# CR: 5.05679012345679
# epoch 1/10 err: 1814.1311575547525
# epoch 2/10 err: 0.13560031172765522
# epoch 3/10 err: 0.09907243063139798
# epoch 4/10 err: 0.09309997307179428
# epoch 5/10 err: 0.09030812919712881
# epoch 6/10 err: 0.08848233744053263
# epoch 7/10 err: 0.08712728965035932
# epoch 8/10 err: 0.08609093974838608
# epoch 9/10 err: 0.08528436661607727
# epoch 10/10 err: 0.08465346607840017
# epoch 11/10 err: 0.08417668544121465
# time_resh: 1.0429131984710693
# Time: 1.09s
#
# Rel Error: 0.08417668544121465
# Tuning param 16
# Doing TnALE Initial Search...
# Iter 0 done
# R: [16, 20, 16, 20, 20]
# Iter 1 done
# R: [20, 24, 16, 25, 24]
# Iter 2 done
# R: [24, 24, 16, 25, 24]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [24, 25, 16, 25, 24]
# Iter 1 done
# R: [24, 25, 16, 25, 24]
# Iter 2 done
# R: [24, 25, 16, 25, 22]
# Iter 3 done
# R: [24, 25, 16, 25, 22]
# Iter 4 done
# R: [24, 25, 16, 25, 22]
# Found structure has ranks [24, 25, 16, 25, 22]
# With TnALE:
# Original: 65536
# Tensor Network: 23072
# CR: 2.840499306518724
# epoch 1/10 err: 3910.822378642111
# epoch 2/10 err: 0.10905637911015148
# epoch 3/10 err: 0.08656393548882359
# epoch 4/10 err: 0.0804432030591493
# epoch 5/10 err: 0.07717346292673787
# epoch 6/10 err: 0.0748488861151535
# epoch 7/10 err: 0.07302423735630945
# epoch 8/10 err: 0.07154471916422034
# epoch 9/10 err: 0.07031314935276486
# epoch 10/10 err: 0.06926443864875381
# epoch 11/10 err: 0.06835591969897355
# time_resh: 2.2723045349121094
# Time: 2.32s
#
# Rel Error: 0.06835591969897355
# Tuning param 32
# Doing TnALE Initial Search...
# Iter 0 done
# R: [16, 20, 20, 20, 20]
# Iter 1 done
# R: [20, 24, 24, 25, 24]
# Iter 2 done
# R: [24, 25, 25, 25, 25]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [24, 25, 25, 25, 25]
# Iter 1 done
# R: [24, 25, 25, 25, 25]
# Iter 2 done
# R: [24, 25, 25, 25, 25]
# Iter 3 done
# R: [24, 25, 25, 25, 25]
# Iter 4 done
# R: [24, 25, 25, 25, 25]
# Found structure has ranks [24, 25, 25, 25, 25]
# With TnALE:
# Original: 65536
# Tensor Network: 29600
# CR: 2.214054054054054
# epoch 1/10 err: 5817.367637465533
# epoch 2/10 err: 0.10375045350317998
# epoch 3/10 err: 0.07906967566460049
# epoch 4/10 err: 0.07204218326971057
# epoch 5/10 err: 0.068281884928407
# epoch 6/10 err: 0.06573376650256048
# epoch 7/10 err: 0.06380535134299908
# epoch 8/10 err: 0.06225094284310383
# epoch 9/10 err: 0.06096892371170328
# epoch 10/10 err: 0.05989844814031665
# epoch 11/10 err: 0.05899141440318434
# time_resh: 3.118863582611084
# Time: 3.16s
#
# Rel Error: 0.05899141440318434
# Original
# 0.5
# 1
# 2
# 4
# 8
# 16
# 32
# {'shape': (8, 8, 16, 8, 8), 'edges': [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (3, 5), (1, 4)], 'ranks': [9, 9, 12, 9, 9, 12, 8], 'iters': 10, 'params': [0.5, 1, 2, 4, 8], 'max_rank': 18}
# Without TnALE:
# Original: 65536
# Tensor Network: 37800
# CR: 1.7337566137566138
# epoch 1/10 err: 4725.6594428478675
# epoch 2/10 err: 0.1268007758477101
# epoch 3/10 err: 0.09129955997187376
# epoch 4/10 err: 0.08124771605778515
# epoch 5/10 err: 0.0760820506480236
# epoch 6/10 err: 0.07267507549808146
# epoch 7/10 err: 0.07017627023872583
# epoch 8/10 err: 0.06820269640150907
# epoch 9/10 err: 0.0665804745978537
# epoch 10/10 err: 0.06521174505614459
# epoch 11/10 err: 0.06403315011056553
# time_resh: 4.565892934799194
# Time: 4.63s
#
# Rel Error: 0.06403315011056553
# Tuning param 0.5
# Doing TnALE Initial Search...
# Iter 0 done
# R: [4, 4, 7, 4, 4, 2, 3]
# Iter 1 done
# R: [4, 4, 7, 4, 4, 2, 3]
# Iter 2 done
# R: [4, 4, 7, 4, 4, 2, 3]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [2, 2, 8, 2, 4, 2, 3]
# Iter 1 done
# R: [2, 2, 8, 2, 4, 2, 3]
# Iter 2 done
# R: [2, 2, 8, 2, 4, 2, 3]
# Iter 3 done
# R: [2, 2, 8, 2, 4, 2, 3]
# Iter 4 done
# R: [2, 2, 8, 2, 4, 2, 3]
# Found structure has ranks [2, 2, 8, 2, 4, 2, 3]
# With TnALE:
# Original: 65536
# Tensor Network: 1408
# CR: 46.54545454545455
# epoch 1/10 err: 48.816443047939984
# epoch 2/10 err: 0.2710755644437738
# epoch 3/10 err: 0.16839331420507203
# epoch 4/10 err: 0.1651926330386416
# epoch 5/10 err: 0.16350745738274705
# epoch 6/10 err: 0.16234246205712874
# epoch 7/10 err: 0.16180883952574382
# epoch 8/10 err: 0.16087858993007756
# epoch 9/10 err: 0.1600862118716483
# epoch 10/10 err: 0.15938220738792133
# epoch 11/10 err: 0.15875558453644228
# time_resh: 0.10671091079711914
# Time: 0.15s
#
# Rel Error: 0.15875558453644228
# Tuning param 1
# Doing TnALE Initial Search...
# Iter 0 done
# R: [4, 4, 11, 4, 4, 2, 3]
# Iter 1 done
# R: [4, 4, 11, 4, 4, 2, 3]
# Iter 2 done
# R: [4, 4, 11, 4, 4, 2, 3]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [2, 4, 11, 4, 4, 2, 3]
# Iter 1 done
# R: [2, 2, 11, 2, 4, 2, 3]
# Iter 2 done
# R: [2, 2, 11, 2, 4, 2, 3]
# Iter 3 done
# R: [2, 2, 11, 2, 4, 2, 3]
# Iter 4 done
# R: [2, 2, 11, 2, 4, 2, 3]
# Found structure has ranks [2, 2, 11, 2, 4, 2, 3]
# With TnALE:
# Original: 65536
# Tensor Network: 1792
# CR: 36.57142857142857
# epoch 1/10 err: 78.29521482827548
# epoch 2/10 err: 0.20791624638114592
# epoch 3/10 err: 0.16593169401629862
# epoch 4/10 err: 0.15650750644267453
# epoch 5/10 err: 0.15289578412054988
# epoch 6/10 err: 0.15174417624165693
# epoch 7/10 err: 0.15039352249074622
# epoch 8/10 err: 0.14956213193419093
# epoch 9/10 err: 0.14874709924965687
# epoch 10/10 err: 0.14847977466162066
# epoch 11/10 err: 0.14786048889750844
# time_resh: 0.14727377891540527
# Time: 0.19s
#
# Rel Error: 0.14786048889750844
# Tuning param 2
# Doing TnALE Initial Search...
# Iter 0 done
# R: [4, 4, 7, 8, 4, 2, 8]
# Iter 1 done
# R: [4, 4, 7, 3, 4, 2, 8]
# Iter 2 done
# R: [4, 4, 7, 3, 4, 2, 8]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [5, 4, 8, 1, 5, 2, 6]
# Iter 1 done
# R: [5, 4, 8, 1, 5, 2, 7]
# Iter 2 done
# R: [5, 4, 6, 1, 5, 2, 7]
# Iter 3 done
# R: [5, 4, 6, 1, 5, 2, 7]
# Iter 4 done
# R: [5, 4, 6, 1, 5, 2, 7]
# Found structure has ranks [5, 4, 6, 1, 5, 2, 7]
# With TnALE:
# Original: 65536
# Tensor Network: 3288
# CR: 19.931873479318735
# epoch 1/10 err: 169.7631743700426
# epoch 2/10 err: 0.19662757623480168
# epoch 3/10 err: 0.1318928103004822
# epoch 4/10 err: 0.12596380034405463
# epoch 5/10 err: 0.1235236986279318
# epoch 6/10 err: 0.1221118568536445
# epoch 7/10 err: 0.12125868774111777
# epoch 8/10 err: 0.12040249344891181
# epoch 9/10 err: 0.11976007395784066
# epoch 10/10 err: 0.11929785114232427
# epoch 11/10 err: 0.11895971544804033
# time_resh: 0.24930787086486816
# Time: 0.29s
#
# Rel Error: 0.11895971544804033
# Tuning param 4
# Doing TnALE Initial Search...
# Iter 0 done
# R: [4, 8, 11, 8, 4, 2, 8]
# Iter 1 done
# R: [4, 8, 11, 12, 4, 2, 8]
# Iter 2 done
# R: [4, 8, 11, 16, 4, 2, 8]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [5, 6, 12, 15, 4, 2, 7]
# Iter 1 done
# R: [5, 6, 13, 15, 4, 2, 8]
# Iter 2 done
# R: [5, 6, 13, 15, 2, 2, 8]
# Iter 3 done
# R: [6, 6, 13, 16, 2, 2, 8]
# Iter 4 done
# R: [6, 6, 13, 16, 2, 2, 8]
# Found structure has ranks [6, 6, 13, 16, 2, 2, 8]
# With TnALE:
# Original: 65536
# Tensor Network: 7968
# CR: 8.224899598393574
# epoch 1/10 err: 863.6907717728889
# epoch 2/10 err: 0.1536183092744398
# epoch 3/10 err: 0.10953563053888497
# epoch 4/10 err: 0.1016709641557
# epoch 5/10 err: 0.0987346439963078
# epoch 6/10 err: 0.09707465535674725
# epoch 7/10 err: 0.09592774951052319
# epoch 8/10 err: 0.0950615488547628
# epoch 9/10 err: 0.09437818677355306
# epoch 10/10 err: 0.09382214232219253
# epoch 11/10 err: 0.0933585574913907
# time_resh: 0.5865826606750488
# Time: 0.64s
#
# Rel Error: 0.0933585574913907
# Tuning param 8
# Doing TnALE Initial Search...
# Iter 0 done
# R: [4, 4, 18, 13, 4, 7, 16]
# Iter 1 done
# R: [4, 4, 18, 13, 4, 7, 18]
# Iter 2 done
# R: [4, 4, 18, 13, 4, 7, 18]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [2, 4, 16, 14, 4, 7, 16]
# Iter 1 done
# R: [2, 4, 16, 14, 4, 7, 16]
# Iter 2 done
# R: [2, 4, 16, 14, 4, 7, 16]
# Iter 3 done
# R: [2, 4, 16, 14, 4, 7, 16]
# Iter 4 done
# R: [2, 4, 16, 14, 4, 7, 16]
# Found structure has ranks [2, 4, 16, 14, 4, 7, 16]
# With TnALE:
# Original: 65536
# Tensor Network: 19296
# CR: 3.396351575456053
# epoch 1/10 err: 1569.5620926205436
# epoch 2/10 err: 0.10308600906141241
# epoch 3/10 err: 0.07942221860599939
# epoch 4/10 err: 0.07396347351514052
# epoch 5/10 err: 0.07131813868168309
# epoch 6/10 err: 0.06981393995130583
# epoch 7/10 err: 0.06863147113310583
# epoch 8/10 err: 0.06778394172206259
# epoch 9/10 err: 0.0671116058047969
# epoch 10/10 err: 0.06661180094941911
# epoch 11/10 err: 0.06599671758422784
# time_resh: 1.9603009223937988
# Time: 2.05s
#
# Rel Error: 0.06599671758422784
# Original
# 0.5
# 1
# 2
# 4
# 8
# {'shape': (8, 8, 16, 8, 8), 'edges': [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (1, 4), (5, 2), (3, 5)], 'ranks': [6, 6, 6, 6, 6, 6, 6, 6], 'iters': 10, 'params': [0.5, 1, 2, 4, 8], 'max_rank': 12}
# Without TnALE:
# Original: 65536
# Tensor Network: 19008
# CR: 3.4478114478114477
# epoch 1/10 err: 2406.817917692992
# epoch 2/10 err: 0.14548052118288304
# epoch 3/10 err: 0.11231987724286274
# epoch 4/10 err: 0.10320577743065933
# epoch 5/10 err: 0.09853256610031287
# epoch 6/10 err: 0.0957197923626177
# epoch 7/10 err: 0.09370446830810818
# epoch 8/10 err: 0.09218814832612017
# epoch 9/10 err: 0.09095100725616038
# epoch 10/10 err: 0.08989645152172834
# epoch 11/10 err: 0.08902090155501353
# time_resh: 2.998985767364502
# Time: 3.07s
#
# Rel Error: 0.08902090155501353
# Tuning param 0.5
# Doing TnALE Initial Search...
# Iter 0 done
# R: [1, 1, 10, 1, 1, 1, 6, 6]
# Iter 1 done
# R: [5, 1, 12, 1, 1, 1, 6, 6]
# Iter 2 done
# R: [5, 1, 12, 1, 1, 1, 6, 6]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [3, 1, 12, 1, 1, 1, 6, 7]
# Iter 1 done
# R: [3, 1, 12, 1, 1, 1, 6, 7]
# Iter 2 done
# R: [3, 1, 12, 1, 1, 1, 6, 7]
# Iter 3 done
# R: [3, 1, 12, 1, 1, 1, 6, 7]
# Iter 4 done
# R: [3, 1, 12, 1, 1, 1, 6, 7]
# Found structure has ranks [3, 1, 12, 1, 1, 1, 6, 7]
# With TnALE:
# Original: 65536
# Tensor Network: 1416
# CR: 46.282485875706215
# epoch 1/10 err: 70.22765317566115
# epoch 2/10 err: 0.2569446079471169
# epoch 3/10 err: 0.16366105711659695
# epoch 4/10 err: 0.15770298627121446
# epoch 5/10 err: 0.15386032364877955
# epoch 6/10 err: 0.15275071238190438
# epoch 7/10 err: 0.15244263684407122
# epoch 8/10 err: 0.15220088255305234
# epoch 9/10 err: 0.15213482138955894
# epoch 10/10 err: 0.15209278371175367
# epoch 11/10 err: 0.15206171059921117
# time_resh: 0.12368464469909668
# Time: 0.17s
#
# Rel Error: 0.15206171059921117
# Tuning param 1
# Doing TnALE Initial Search...
# Iter 0 done
# R: [1, 1, 10, 1, 6, 6, 1, 6]
# Iter 1 done
# R: [1, 1, 10, 1, 6, 6, 1, 6]
# Iter 2 done
# R: [1, 1, 10, 1, 6, 6, 1, 6]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [1, 1, 8, 2, 4, 6, 1, 4]
# Iter 1 done
# R: [1, 1, 8, 2, 4, 6, 1, 4]
# Iter 2 done
# R: [1, 1, 8, 2, 4, 7, 1, 4]
# Iter 3 done
# R: [1, 1, 8, 2, 4, 7, 1, 4]
# Iter 4 done
# R: [1, 1, 8, 2, 4, 7, 1, 4]
# Found structure has ranks [1, 1, 8, 2, 4, 7, 1, 4]
# With TnALE:
# Original: 65536
# Tensor Network: 2272
# CR: 28.845070422535212
# epoch 1/10 err: 75.96646622547044
# epoch 2/10 err: 0.2655787992779868
# epoch 3/10 err: 0.14316337043453845
# epoch 4/10 err: 0.1390198598528706
# epoch 5/10 err: 0.13887322761430004
# epoch 6/10 err: 0.138398383913425
# epoch 7/10 err: 0.13819842090548637
# epoch 8/10 err: 0.1380747307535331
# epoch 9/10 err: 0.13787495938593616
# epoch 10/10 err: 0.13805152858359498
# epoch 11/10 err: 0.13782405149803065
# time_resh: 0.17912983894348145
# Time: 0.23s
#
# Rel Error: 0.13782405149803065
# Tuning param 2
# Doing TnALE Initial Search...
# Iter 0 done
# R: [1, 1, 10, 1, 6, 6, 1, 6]
# Iter 1 done
# R: [1, 1, 10, 1, 6, 6, 1, 6]
# Iter 2 done
# R: [1, 1, 10, 1, 6, 6, 1, 6]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [1, 1, 8, 1, 6, 6, 1, 7]
# Iter 1 done
# R: [1, 1, 8, 1, 6, 4, 1, 7]
# Iter 2 done
# R: [1, 1, 8, 1, 6, 4, 1, 7]
# Iter 3 done
# R: [1, 1, 8, 1, 6, 4, 1, 7]
# Iter 4 done
# R: [1, 1, 8, 1, 4, 4, 1, 8]
# Found structure has ranks [1, 1, 8, 1, 4, 4, 1, 8]
# With TnALE:
# Original: 65536
# Tensor Network: 2464
# CR: 26.5974025974026
# epoch 1/10 err: 56.00682371026871
# epoch 2/10 err: 0.2775027982227603
# epoch 3/10 err: 0.13195735202983808
# epoch 4/10 err: 0.1263229480329433
# epoch 5/10 err: 0.12535504111013857
# epoch 6/10 err: 0.12500187533762921
# epoch 7/10 err: 0.12481424575453676
# epoch 8/10 err: 0.1246745536340539
# epoch 9/10 err: 0.12454340319737127
# epoch 10/10 err: 0.12440829675649269
# epoch 11/10 err: 0.12426857725881817
# time_resh: 0.19065523147583008
# Time: 0.24s
#
# Rel Error: 0.12426857725881817
# Tuning param 4
# Doing TnALE Initial Search...
# Iter 0 done
# R: [1, 6, 12, 1, 6, 6, 1, 10]
# Iter 1 done
# R: [1, 6, 12, 1, 6, 6, 1, 10]
# Iter 2 done
# R: [1, 6, 12, 1, 6, 6, 1, 10]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [1, 4, 12, 1, 6, 6, 1, 10]
# Iter 1 done
# R: [1, 4, 12, 1, 6, 6, 1, 10]
# Iter 2 done
# R: [1, 2, 12, 1, 6, 4, 1, 10]
# Iter 3 done
# R: [1, 2, 12, 1, 7, 4, 1, 11]
# Iter 4 done
# R: [1, 2, 12, 1, 7, 4, 1, 11]
# Found structure has ranks [1, 2, 12, 1, 7, 4, 1, 11]
# With TnALE:
# Original: 65536
# Tensor Network: 5768
# CR: 11.361997226074896
# epoch 1/10 err: 162.90857737270727
# epoch 2/10 err: 0.13711531076014524
# epoch 3/10 err: 0.10995518600118773
# epoch 4/10 err: 0.10667261965448013
# epoch 5/10 err: 0.10543760716117248
# epoch 6/10 err: 0.10502038560445937
# epoch 7/10 err: 0.10456775849462241
# epoch 8/10 err: 0.10430269936919666
# epoch 9/10 err: 0.10403279448084576
# epoch 10/10 err: 0.10407798737999072
# epoch 11/10 err: 0.1039966497435469
# time_resh: 0.5527923107147217
# Time: 0.59s
#
# Rel Error: 0.1039966497435469
# Tuning param 8
# Doing TnALE Initial Search...
# Iter 0 done
# R: [10, 6, 10, 1, 1, 10, 6, 6]
# Iter 1 done
# R: [10, 6, 10, 1, 1, 10, 6, 6]
# Iter 2 done
# R: [10, 6, 10, 1, 1, 10, 6, 6]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [8, 6, 11, 1, 1, 10, 7, 7]
# Iter 1 done
# R: [8, 6, 11, 1, 1, 10, 5, 7]
# Iter 2 done
# R: [8, 7, 11, 1, 1, 10, 3, 7]
# Iter 3 done
# R: [8, 7, 11, 1, 1, 10, 3, 5]
# Iter 4 done
# R: [8, 7, 11, 1, 1, 10, 3, 5]
# Found structure has ranks [8, 7, 11, 1, 1, 10, 3, 5]
# With TnALE:
# Original: 65536
# Tensor Network: 10712
# CR: 6.117998506348021
# epoch 1/10 err: 595.2125894782444
# epoch 2/10 err: 0.12005437876826511
# epoch 3/10 err: 0.1002738786877214
# epoch 4/10 err: 0.095545269610036
# epoch 5/10 err: 0.09354158770628303
# epoch 6/10 err: 0.09227068371469944
# epoch 7/10 err: 0.09120146749412951
# epoch 8/10 err: 0.09042144339344015
# epoch 9/10 err: 0.09000268871399365
# epoch 10/10 err: 0.08953944609808766
# epoch 11/10 err: 0.08910131521123858
# time_resh: 1.099531650543213
# Time: 1.15s
#
# Rel Error: 0.08910131521123858
# Original
# 0.5
# 1
# 2
# 4
# 8
# {'shape': (8, 8, 16, 8, 8), 'edges': [(1, 2), (2, 3), (3, 4), (4, 5), (5, 1), (5, 2), (5, 3), (4, 1), (4, 2), (3, 1)], 'ranks': [4, 4, 4, 4, 4, 4, 4, 4, 4, 4], 'iters': 10, 'params': [0.5, 1, 2, 4], 'max_rank': 10}
# Without TnALE:
# Original: 65536
# Tensor Network: 12288
# CR: 5.333333333333333
# epoch 1/10 err: 1917.661397360335
# epoch 2/10 err: 0.1913905111091716
# epoch 3/10 err: 0.12422622474330872
# epoch 4/10 err: 0.10756584159841624
# epoch 5/10 err: 0.10177067873205055
# epoch 6/10 err: 0.09888106406164292
# epoch 7/10 err: 0.09702079757643958
# epoch 8/10 err: 0.09564605189686158
# epoch 9/10 err: 0.09455949222537036
# epoch 10/10 err: 0.0936657638033884
# epoch 11/10 err: 0.09290984531996217
# time_resh: 0.7025985717773438
# Time: 0.75s
#
# Rel Error: 0.09290984531996217
# Tuning param 0.5
# Doing TnALE Initial Search...
# Iter 0 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Iter 1 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Iter 2 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [2, 2, 3, 3, 2, 2, 4, 2, 2, 3]
# Iter 1 done
# R: [2, 2, 4, 3, 2, 2, 3, 2, 2, 3]
# Iter 2 done
# R: [2, 2, 4, 3, 2, 2, 3, 2, 2, 3]
# Iter 3 done
# R: [2, 3, 4, 3, 2, 2, 3, 2, 2, 1]
# Iter 4 done
# R: [2, 4, 4, 3, 2, 2, 3, 2, 2, 1]
# Found structure has ranks [2, 4, 4, 3, 2, 2, 3, 2, 2, 1]
# With TnALE:
# Original: 65536
# Tensor Network: 1664
# CR: 39.38461538461539
# epoch 1/10 err: 115.30867334619039
# epoch 2/10 err: 0.21454692007141285
# epoch 3/10 err: 0.17582664608923934
# epoch 4/10 err: 0.1674454884523553
# epoch 5/10 err: 0.16435167415359853
# epoch 6/10 err: 0.16197399243447735
# epoch 7/10 err: 0.1606843350666016
# epoch 8/10 err: 0.15972538048547208
# epoch 9/10 err: 0.1601790479285924
# epoch 10/10 err: 0.1591541690699278
# epoch 11/10 err: 0.15846711106784298
# time_resh: 0.12186789512634277
# Time: 0.17s
#
# Rel Error: 0.15846711106784298
# Tuning param 1
# Doing TnALE Initial Search...
# Iter 0 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Iter 1 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Iter 2 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [2, 2, 2, 2, 2, 2, 5, 5, 2, 4]
# Iter 1 done
# R: [2, 2, 2, 2, 2, 2, 5, 5, 2, 4]
# Iter 2 done
# R: [2, 2, 2, 2, 2, 2, 5, 5, 2, 4]
# Iter 3 done
# R: [2, 2, 2, 2, 2, 2, 5, 5, 2, 4]
# Iter 4 done
# R: [2, 2, 2, 2, 2, 2, 5, 5, 2, 4]
# Found structure has ranks [2, 2, 2, 2, 2, 2, 5, 5, 2, 4]
# With TnALE:
# Original: 65536
# Tensor Network: 2944
# CR: 22.26086956521739
# epoch 1/10 err: 206.82063263433523
# epoch 2/10 err: 0.1853542373157912
# epoch 3/10 err: 0.14501312407814151
# epoch 4/10 err: 0.13854631656859975
# epoch 5/10 err: 0.13662352057762808
# epoch 6/10 err: 0.13558611665377565
# epoch 7/10 err: 0.13468399712254764
# epoch 8/10 err: 0.1336994311786133
# epoch 9/10 err: 0.13457619943035729
# epoch 10/10 err: 0.13335128912077493
# epoch 11/10 err: 0.1334969220918496
# time_resh: 0.21250200271606445
# Time: 0.25s
#
# Rel Error: 0.1334969220918496
# Tuning param 2
# Doing TnALE Initial Search...
# Iter 0 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Iter 1 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Iter 2 done
# R: [4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [2, 2, 4, 2, 2, 2, 6, 5, 2, 4]
# Iter 1 done
# R: [2, 1, 4, 2, 2, 2, 6, 5, 2, 4]
# Iter 2 done
# R: [2, 1, 5, 2, 2, 2, 4, 6, 2, 4]
# Iter 3 done
# R: [2, 1, 5, 2, 2, 2, 4, 6, 2, 4]
# Iter 4 done
# R: [2, 1, 5, 2, 2, 2, 4, 6, 2, 4]
# Found structure has ranks [2, 1, 5, 2, 2, 2, 4, 6, 2, 4]
# With TnALE:
# Original: 65536
# Tensor Network: 5152
# CR: 12.720496894409937
# epoch 1/10 err: 207.55318145416473
# epoch 2/10 err: 0.17214730210369625
# epoch 3/10 err: 0.13080445742293675
# epoch 4/10 err: 0.1252926621789244
# epoch 5/10 err: 0.12317353065791005
# epoch 6/10 err: 0.12225220602672737
# epoch 7/10 err: 0.12216161489949998
# epoch 8/10 err: 0.12171918579355911
# epoch 9/10 err: 0.12124375348306321
# epoch 10/10 err: 0.12106359787329594
# epoch 11/10 err: 0.1207403279940874
# time_resh: 0.4514029026031494
# Time: 0.50s
#
# Rel Error: 0.1207403279940874
# Tuning param 4
# Doing TnALE Initial Search...
# Iter 0 done
# R: [8, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Iter 1 done
# R: [3, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Iter 2 done
# R: [3, 4, 4, 4, 4, 4, 4, 4, 4, 4]
# Doing TnALE Concrete Search...
# Iter 0 done
# R: [3, 2, 5, 2, 2, 4, 5, 4, 2, 4]
# Iter 1 done
# R: [4, 2, 5, 2, 2, 4, 6, 4, 2, 4]
# Iter 2 done
# R: [4, 2, 6, 3, 2, 2, 6, 4, 2, 4]
# Iter 3 done
# R: [5, 2, 6, 1, 2, 2, 6, 4, 2, 5]
# Iter 4 done
# R: [5, 2, 6, 1, 2, 2, 6, 4, 2, 6]
# Found structure has ranks [5, 2, 6, 1, 2, 2, 6, 4, 2, 6]
# With TnALE:
# Original: 65536
# Tensor Network: 8992
# CR: 7.288256227758007
# epoch 1/10 err: 465.3410934165629
# epoch 2/10 err: 0.1804894198652626
# epoch 3/10 err: 0.10338817112584539
# epoch 4/10 err: 0.1007225361047666
# epoch 5/10 err: 0.09998900531982638
# epoch 6/10 err: 0.09977191103420188
# epoch 7/10 err: 0.0995211428028265
# epoch 8/10 err: 0.09917174823846936
# epoch 9/10 err: 0.09927717780358047
# epoch 10/10 err: 0.09905650395014548
# epoch 11/10 err: 0.09905033039342448
# time_resh: 1.2029569149017334
# Time: 1.25s
#
# Rel Error: 0.09905033039342448
# Original
# 0.5
# 1
# 2
# 4
